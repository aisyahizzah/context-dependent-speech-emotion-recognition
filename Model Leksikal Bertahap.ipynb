# %% [markdown]
# # Pembangunan Model Leksikal Bertahap - Sistem Pengenal Emosi Cakapan

# %% [markdown]
# ## Library Preparation

# %%
# !pip install imbalanced-learn
# !pip install transformers
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.4.3)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->imbalanced-learn) (1.0.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.6.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.0.1)
# Requirement already satisfied: huggingface-hub==0.0.8 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.8)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.19.5)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.9.1+cu101)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.1.95)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.4.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.8.1+cu101)
# Requirement already satisfied: transformers<5.0.0,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.6.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.2.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.22.2.post1)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence_transformers) (3.7.4.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (0.0.45)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (0.10.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (20.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (4.0.1)
# Requirement already satisfied: huggingface-hub==0.0.8 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (0.0.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence_transformers) (7.1.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence_transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers<5.0.0,>=3.1.0->sentence_transformers) (3.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (2020.12.5)

# %%
import os

import numpy as np
import pandas as pd
import statistics
import joblib
import torch

import nltk
from nltk.tokenize import word_tokenize
from transformers import BertTokenizer, AutoModel

import gensim
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
from sentence_transformers import models, losses
from sentence_transformers import SentencesDataset, SentenceTransformer
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator
from torch.utils.data import DataLoader
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from keras import backend
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras import layers
from imblearn.over_sampling import SMOTE

from google.colab import drive
from google.colab import files
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
drive.mount('/content/gdrive')
drive_dir = "/content/gdrive/MyDrive/Teknik Informatika/Semester 7/TUGAS AKHIR/TA 2"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Feature Extraction

# %%
data = joblib.load(drive_dir + '/Eksperimen/Data/stopword.pkl')

# %%
tfidf_vectorizer = TfidfVectorizer()
feature_tfidf = tfidf_vectorizer.fit_transform(data['Transkripsi'])
feature_tfidf = np.array(feature_tfidf.todense())
feature_tfidf.shape
# Out:
# (10822, 5017)

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Construct Sequential Data

# %%
def construct_sequential(id, data):
  sequential_datas = []
  new_data= []
  for i in range(len(id)):
    if id[i].endswith('001'):
      sequential_datas.append(new_data)
      new_data = []
    new_data.append(data[i])
  sequential_datas.append(new_data)

  return np.array(sequential_datas, dtype=object)[1:]

# %%
def construct_abstract(id, abstraksi):
  new_abstraksi = []
  for i in range(len(id)):
    if id[i].endswith('001'):
      new_abstraksi.append(abstraksi[i])

  return np.array(new_abstraksi, dtype=object)

# %%
id = data['ID Ucapan']
sequential_features_tfidf = construct_sequential(id, feature_tfidf)
print(sequential_features_tfidf.shape)
# Out:
# (2003,)

# %% [markdown]
# ### Prepare Labels

# %%
encoder_ucapan = OneHotEncoder(sparse=False)
labels = np.array(data['Label Emosi']).reshape(-1, 1)
labels = encoder_ucapan.fit_transform(labels)
labels = construct_sequential(id, labels)
labels.shape
# Out:
# (2003,)

# %%
abstraksi = construct_abstract(id, data['Abstraksi Emosi'])
encoder_cakapan = OneHotEncoder(sparse=False)
abstraksi = abstraksi.reshape(-1, 1)
abstraksi = encoder_cakapan.fit_transform(abstraksi)
abstraksi.shape
# Out:
# (2003, 6)

# %% [markdown]
# ### Split Train and Test Data

# %%
X = sequential_features_tfidf
y_sequential = labels
y = abstraksi

# %%
X = tf.keras.preprocessing.sequence.pad_sequences(X, padding="post", dtype='float32')
y_sequential = tf.keras.preprocessing.sequence.pad_sequences(y_sequential, padding="post", dtype='float32')
y = tf.keras.preprocessing.sequence.pad_sequences(y, padding="post", dtype='float32')
print(X.shape, y.shape, y_sequential.shape)
# Out:
# (2003, 15, 5017) (2003, 6) (2003, 15, 6)

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.15, random_state=42)
for train_index, test_index in sss.split(X, y):
  train_index, test_index = train_index, test_index

# %% [markdown]
# ## Modelling Preparation

# %% [markdown]
# ### Define Model

# %%
def get_contextual_model(shape, label_shape):
  model = Sequential()
  model.add(layers.Masking(mask_value=0, input_shape=shape))
  model.add(layers.GRU(32, return_sequences=True))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(label_shape, activation='softmax'))
  return model

# %%
def get_classification_model(shape, label_shape):
  model = Sequential()
  model.add(layers.Masking(mask_value=0, input_shape=shape))
  model.add(layers.GRU(32, return_sequences=False))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(label_shape, activation='softmax'))
  return model

# %% [markdown]
# ### Define Training Parameter

# %%
batch_size = 32
epochs = 10
validation_split = 0.2
optimizer = 'adam'
loss = 'categorical_crossentropy'
metrics = ['accuracy']
callbacks = [EarlyStopping(monitor='val_accuracy', mode='max', min_delta=0.0001, patience=2, restore_best_weights=True)]

# %% [markdown]
# ### Define Schema Experiment

# %%
def train_5fold_cv(X, y, shape, label_shape, return_sequences):

  loss_score = []
  accuracy_score = []  

  cv = KFold(n_splits=5, random_state=42, shuffle=True)

  for train_index, val_index in cv.split(X):
      
      X_train, X_val, y_train, y_val = X[train_index], X[val_index], y[train_index], y[val_index]
      
      model = None
      if return_sequences :
        model = get_contextual_model(shape, label_shape)
      else :
        model = get_classification_model(shape, label_shape)
      model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
      model.fit(X_train, y_train,
              validation_data=(X_val, y_val),
              epochs=epochs,
              batch_size=batch_size,
              callbacks=callbacks)
      
      l, a = model.evaluate(X_val, y_val)
      loss_score.append(l)
      accuracy_score.append(a)
  
  loss_score = np.round(np.mean(loss_score), 4)
  accuracy_score = np.round(np.mean(accuracy_score), 4)
  print("Loss Score : ", loss_score, "Accuracy Score : ", accuracy_score)
  return loss_score, accuracy_score

# %%
def train_stratified_random_sampling(X_train, y_train, X_test, y_test, shape, label_shape, return_sequences):

  model = None
  if return_sequences :
    model = get_contextual_model(shape, label_shape)
  else :
    model = get_classification_model(shape, label_shape)
  model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
  model.fit(X_train, y_train,
            validation_data=(X_test, y_test),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=callbacks)
      
  loss_score, accuracy_score = model.evaluate(X_test, y_test)
  loss_score = np.round(np.mean(loss_score), 4)
  accuracy_score = np.round(np.mean(accuracy_score), 4)

  print("Loss Score : ", loss_score, "Accuracy Score : ", accuracy_score)
  
  return model, accuracy_score

# %% [markdown]
# ## Modul 1 : Pembangunan Contextual Model

# %%
X_train, y_train = X[train_index], y_sequential[train_index]
X_test, y_test = X[test_index], y_sequential[test_index]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1702, 15, 5017) (1702, 15, 6)
# (301, 15, 5017) (301, 15, 6)

# %%
def run_contextual_model(X_train, y_train, X_test, y_test, n):
  model = None
  best_acc = 0
  for i in range(n):
    model, accuracy_score = train_stratified_random_sampling(X_train, y_train, X_test, y_test, X_train.shape[1:], y_train.shape[2], True)
    if best_acc < accuracy_score:
      best_acc = accuracy_score
      best_model = model
  return best_model

# %%
contextual_model = run_contextual_model(X_train, y_train, X_test, y_test, 5)
# Out:
# Epoch 1/10
# 54/54 [==============================] - 8s 53ms/step - loss: 0.6051 - accuracy: 0.3519 - val_loss: 0.4996 - val_accuracy: 0.3946
# Epoch 2/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.5115 - accuracy: 0.3927 - val_loss: 0.4839 - val_accuracy: 0.3576
# Epoch 3/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.4823 - accuracy: 0.4172 - val_loss: 0.4674 - val_accuracy: 0.4125
# Epoch 4/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.4441 - accuracy: 0.5126 - val_loss: 0.4417 - val_accuracy: 0.4617
# Epoch 5/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.3855 - accuracy: 0.6086 - val_loss: 0.4352 - val_accuracy: 0.4955
# Epoch 6/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.3074 - accuracy: 0.7080 - val_loss: 0.4466 - val_accuracy: 0.4936
# Epoch 7/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.2507 - accuracy: 0.7711 - val_loss: 0.4896 - val_accuracy: 0.4898
# 10/10 [==============================] - 0s 11ms/step - loss: 0.4352 - accuracy: 0.4955
# Loss Score :  0.4352 Accuracy Score :  0.4955
# Epoch 1/10
# 54/54 [==============================] - 8s 60ms/step - loss: 0.6261 - accuracy: 0.3048 - val_loss: 0.5022 - val_accuracy: 0.3429
# Epoch 2/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.5011 - accuracy: 0.3928 - val_loss: 0.4819 - val_accuracy: 0.4151
# Epoch 3/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.4840 - accuracy: 0.4808 - val_loss: 0.4589 - val_accuracy: 0.4400
# Epoch 4/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.4290 - accuracy: 0.5466 - val_loss: 0.4427 - val_accuracy: 0.4770
# Epoch 5/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.3450 - accuracy: 0.6545 - val_loss: 0.4488 - val_accuracy: 0.4974
# Epoch 6/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.3036 - accuracy: 0.7034 - val_loss: 0.4699 - val_accuracy: 0.4949
# Epoch 7/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.2657 - accuracy: 0.7536 - val_loss: 0.4845 - val_accuracy: 0.4981
# Epoch 8/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.2339 - accuracy: 0.7799 - val_loss: 0.5209 - val_accuracy: 0.4943
# Epoch 9/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.2041 - accuracy: 0.8105 - val_loss: 0.5535 - val_accuracy: 0.4860
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4845 - accuracy: 0.4981
# Loss Score :  0.4845 Accuracy Score :  0.4981
# Epoch 1/10
# 54/54 [==============================] - 8s 52ms/step - loss: 0.6106 - accuracy: 0.3180 - val_loss: 0.5043 - val_accuracy: 0.3429
# Epoch 2/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.5336 - accuracy: 0.3775 - val_loss: 0.4837 - val_accuracy: 0.3595
# Epoch 3/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.4847 - accuracy: 0.4373 - val_loss: 0.4613 - val_accuracy: 0.4189
# Epoch 4/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.4432 - accuracy: 0.5206 - val_loss: 0.4375 - val_accuracy: 0.4713
# Epoch 5/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.3729 - accuracy: 0.6215 - val_loss: 0.4312 - val_accuracy: 0.4808
# Epoch 6/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.3129 - accuracy: 0.6964 - val_loss: 0.4384 - val_accuracy: 0.5051
# Epoch 7/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.2627 - accuracy: 0.7528 - val_loss: 0.4650 - val_accuracy: 0.5038
# Epoch 8/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.2255 - accuracy: 0.7891 - val_loss: 0.4977 - val_accuracy: 0.5000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.4384 - accuracy: 0.5051
# Loss Score :  0.4384 Accuracy Score :  0.5051
# Epoch 1/10
# 54/54 [==============================] - 9s 54ms/step - loss: 0.6116 - accuracy: 0.3394 - val_loss: 0.4993 - val_accuracy: 0.3429
# Epoch 2/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.5158 - accuracy: 0.3740 - val_loss: 0.4815 - val_accuracy: 0.4144
# Epoch 3/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.4890 - accuracy: 0.4507 - val_loss: 0.4637 - val_accuracy: 0.4125
# Epoch 4/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.4331 - accuracy: 0.5105 - val_loss: 0.4421 - val_accuracy: 0.4674
# Epoch 5/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.3634 - accuracy: 0.6358 - val_loss: 0.4378 - val_accuracy: 0.4866
# Epoch 6/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.2926 - accuracy: 0.7298 - val_loss: 0.4482 - val_accuracy: 0.4923
# Epoch 7/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.2523 - accuracy: 0.7710 - val_loss: 0.4829 - val_accuracy: 0.4879
# Epoch 8/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.2047 - accuracy: 0.8084 - val_loss: 0.5071 - val_accuracy: 0.4917
# 10/10 [==============================] - 0s 12ms/step - loss: 0.4482 - accuracy: 0.4923
# Loss Score :  0.4482 Accuracy Score :  0.4923
# Epoch 1/10
# 54/54 [==============================] - 8s 53ms/step - loss: 0.5943 - accuracy: 0.3721 - val_loss: 0.4994 - val_accuracy: 0.3429
# Epoch 2/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.5118 - accuracy: 0.3888 - val_loss: 0.4814 - val_accuracy: 0.3851
# Epoch 3/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.4835 - accuracy: 0.4477 - val_loss: 0.4632 - val_accuracy: 0.4080
# Epoch 4/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.4490 - accuracy: 0.4861 - val_loss: 0.4461 - val_accuracy: 0.4502
# Epoch 5/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.3676 - accuracy: 0.5981 - val_loss: 0.4315 - val_accuracy: 0.4904
# Epoch 6/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.3064 - accuracy: 0.7117 - val_loss: 0.4419 - val_accuracy: 0.4974
# Epoch 7/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.2483 - accuracy: 0.7655 - val_loss: 0.4654 - val_accuracy: 0.5013
# Epoch 8/10
# 54/54 [==============================] - 1s 21ms/step - loss: 0.2113 - accuracy: 0.8081 - val_loss: 0.5070 - val_accuracy: 0.4936
# Epoch 9/10
# 54/54 [==============================] - 1s 22ms/step - loss: 0.1848 - accuracy: 0.8251 - val_loss: 0.5492 - val_accuracy: 0.4898
# 10/10 [==============================] - 0s 11ms/step - loss: 0.4654 - accuracy: 0.5013
# Loss Score :  0.4654 Accuracy Score :  0.5013

# %%
contextual_model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4384 - accuracy: 0.5051
# [0.43836164474487305, 0.5051085352897644]

# %%
contextual_model.save(drive_dir + "/Eksperimen/Model/model_leksikal_bertahap_contextual.h5")

# %%
contextual_model = keras.models.load_model(drive_dir + "/Eksperimen/Model/model_leksikal_bertahap_contextual.h5")
contextual_model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 2s 27ms/step - loss: 0.4384 - accuracy: 0.5051
# [0.43836164474487305, 0.5051085352897644]

# %% [markdown]
# ### Extract Contextual Features

# %%
contextual_model = keras.models.load_model(drive_dir + "/Eksperimen/Model/model_leksikal_bertahap_contextual.h5")
contextual_model.evaluate(X[test_index], y_sequential[test_index])
# Out:
# 10/10 [==============================] - 2s 38ms/step - loss: 0.4384 - accuracy: 0.5051
# [0.43836164474487305, 0.5051085352897644]

# %%
def extract_contextual_features(model, idx_output, data):
  get_relu_output = backend.function([model.layers[0].input], [model.layers[idx_output].output])
  relu_output = get_relu_output([data])
  return np.array(relu_output[0])

# %%
contextual_features = extract_contextual_features(contextual_model, 3, X)
contextual_features.shape
# Out:
# (2003, 15, 64)

# %%
for a in X[test_index][100][14]:
  if a != 0.0 : print(a)

# %% [markdown]
# ## Modul 2 : Pembangunan Classification Model

# %%
X_train, y_train = extract_contextual_features(contextual_model, 3, X[train_index]), y[train_index]
X_test, y_test = extract_contextual_features(contextual_model, 3, X[test_index]), y[test_index]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1702, 15, 64) (1702, 6)
# (301, 15, 64) (301, 6)

# %%
def run_classification_model(X_train, y_train, X_test, y_test, n):
  model = None
  best_acc = 0
  for i in range(n):
    model, accuracy_score = train_stratified_random_sampling(X_train, y_train, X_test, y_test, X_train.shape[1:], y_train.shape[1], False)
    if best_acc < accuracy_score:
      best_acc = accuracy_score
      best_model = model
  return best_model

# %%
classification_model = run_classification_model(X_train, y_train, X_test, y_test, 5)
# Out:
# Epoch 1/10
# 54/54 [==============================] - 5s 28ms/step - loss: 1.4860 - accuracy: 0.4351 - val_loss: 1.6066 - val_accuracy: 0.2625
# Epoch 2/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7658 - accuracy: 0.7381 - val_loss: 1.5582 - val_accuracy: 0.2392
# Epoch 3/10
# 54/54 [==============================] - 0s 6ms/step - loss: 0.6040 - accuracy: 0.7876 - val_loss: 1.5920 - val_accuracy: 0.2292
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6066 - accuracy: 0.2625
# Loss Score :  1.6066 Accuracy Score :  0.2625
# Epoch 1/10
# 54/54 [==============================] - 5s 32ms/step - loss: 1.4467 - accuracy: 0.4546 - val_loss: 1.5872 - val_accuracy: 0.3621
# Epoch 2/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7770 - accuracy: 0.7220 - val_loss: 1.6420 - val_accuracy: 0.1794
# Epoch 3/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7030 - accuracy: 0.7590 - val_loss: 1.6195 - val_accuracy: 0.1960
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5872 - accuracy: 0.3621
# Loss Score :  1.5872 Accuracy Score :  0.3621
# Epoch 1/10
# 54/54 [==============================] - 5s 28ms/step - loss: 1.4521 - accuracy: 0.4307 - val_loss: 1.5980 - val_accuracy: 0.3189
# Epoch 2/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7937 - accuracy: 0.7324 - val_loss: 1.6914 - val_accuracy: 0.1827
# Epoch 3/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6630 - accuracy: 0.7649 - val_loss: 1.6465 - val_accuracy: 0.1860
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5980 - accuracy: 0.3189
# Loss Score :  1.598 Accuracy Score :  0.3189
# Epoch 1/10
# 54/54 [==============================] - 5s 30ms/step - loss: 1.3781 - accuracy: 0.4662 - val_loss: 1.6282 - val_accuracy: 0.1927
# Epoch 2/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7094 - accuracy: 0.7563 - val_loss: 1.6399 - val_accuracy: 0.1960
# Epoch 3/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6243 - accuracy: 0.7890 - val_loss: 1.7112 - val_accuracy: 0.1860
# Epoch 4/10
# 54/54 [==============================] - 0s 6ms/step - loss: 0.5971 - accuracy: 0.7896 - val_loss: 1.5780 - val_accuracy: 0.2558
# Epoch 5/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.5415 - accuracy: 0.8207 - val_loss: 1.6704 - val_accuracy: 0.2292
# Epoch 6/10
# 54/54 [==============================] - 0s 6ms/step - loss: 0.5938 - accuracy: 0.7950 - val_loss: 1.6457 - val_accuracy: 0.2292
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5780 - accuracy: 0.2558
# Loss Score :  1.578 Accuracy Score :  0.2558
# Epoch 1/10
# 54/54 [==============================] - 5s 29ms/step - loss: 1.3474 - accuracy: 0.5310 - val_loss: 1.6007 - val_accuracy: 0.2226
# Epoch 2/10
# 54/54 [==============================] - 0s 6ms/step - loss: 0.7070 - accuracy: 0.7617 - val_loss: 1.5906 - val_accuracy: 0.2193
# Epoch 3/10
# 54/54 [==============================] - 0s 6ms/step - loss: 0.6816 - accuracy: 0.7611 - val_loss: 1.5520 - val_accuracy: 0.4120
# Epoch 4/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6059 - accuracy: 0.7899 - val_loss: 1.5999 - val_accuracy: 0.2458
# Epoch 5/10
# 54/54 [==============================] - 0s 7ms/step - loss: 0.5385 - accuracy: 0.8167 - val_loss: 1.5454 - val_accuracy: 0.3821
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5520 - accuracy: 0.4120
# Loss Score :  1.552 Accuracy Score :  0.412

# %%
classification_model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2955 - accuracy: 0.5714
# [1.2955167293548584, 0.5714285969734192]

# %%
classification_model = keras.models.load_model(drive_dir + "/Eksperimen/Model/model_leksikal_bertahap_classification_6.h5")
pred = classification_model.predict(X_test)
y_pred = encoder_cakapan.inverse_transform(pred)
y_true = encoder_cakapan.inverse_transform(y_test)
print(classification_report(y_true, y_pred, digits=4))
print(confusion_matrix(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Jijik     0.0000    0.0000    0.0000         1
#        Marah     0.5667    0.4048    0.4722        42
#        Sedih     0.4907    0.6163    0.5464        86
#       Senang     0.6525    0.6814    0.6667       113
#        Takut     0.0000    0.0000    0.0000         9
#     Terkejut     0.5556    0.5000    0.5263        50
#
#     accuracy                         0.5714       301
#    macro avg     0.3776    0.3671    0.3686       301
# weighted avg     0.5565    0.5714    0.5597       301
#
# [[ 0  0  1  0  0  0]
#  [ 0 17 18  3  0  4]
#  [ 0  6 53 21  0  6]
#  [ 0  2 25 77  0  9]
#  [ 0  1  4  3  0  1]
#  [ 0  4  7 14  0 25]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
classification_model.save(drive_dir + "/Eksperimen/Model/model_leksikal_bertahap_classification_6.h5")

# %% [markdown]
# ### Delete Small Size Label Data

# %%
def get_label_idxs(list, label):
  idxs = []
  for i in range(len(list)):
    for l in label:
      if list[i] == l:
        idxs.append(i)
  return np.array(idxs)

# %%
def delete_elArr_by_idx(arr, idx):
  new_arr = []
  for i in range(len(arr)):
    if i not in idx:
      new_arr.append(arr[i])
  return np.array(new_arr)

# %%
dec_abstraksi = encoder_cakapan.inverse_transform(abstraksi)
del_idxs = get_label_idxs(dec_abstraksi, ["Jijik", "Takut"])
updated_features = delete_elArr_by_idx(contextual_features, del_idxs)
updated_labels = delete_elArr_by_idx(dec_abstraksi, del_idxs)
print(updated_features.shape, updated_labels.shape)
# Out:
# (1936, 15, 64) (1936, 1)

# %%
encoder_cakapan_2 = OneHotEncoder(sparse=False)
updated_labels = updated_labels.reshape(-1, 1)
updated_labels = encoder_cakapan_2.fit_transform(updated_labels)
updated_labels.shape
# Out:
# (1936, 4)

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.15, random_state=42)
for train_index, test_index in sss.split(updated_features, updated_labels):
  train_index, test_index = train_index, test_index

# %%
X_train, y_train = updated_features[train_index], updated_labels[train_index]
X_test, y_test = updated_features[test_index], updated_labels[test_index]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1645, 15, 64) (1645, 4)
# (291, 15, 64) (291, 4)

# %%
classification_model = run_classification_model(X_train, y_train, X_test, y_test, 5)
# Out:
# Epoch 1/10
# 52/52 [==============================] - 7s 42ms/step - loss: 1.1388 - accuracy: 0.5035 - val_loss: 0.9061 - val_accuracy: 0.6357
# Epoch 2/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.6196 - accuracy: 0.7814 - val_loss: 0.9272 - val_accuracy: 0.6598
# Epoch 3/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5601 - accuracy: 0.7756 - val_loss: 0.8913 - val_accuracy: 0.6873
# Epoch 4/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.5611 - accuracy: 0.7875 - val_loss: 0.8671 - val_accuracy: 0.6770
# Epoch 5/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5168 - accuracy: 0.8130 - val_loss: 0.9031 - val_accuracy: 0.6804
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8913 - accuracy: 0.6873
# Loss Score :  0.8913 Accuracy Score :  0.6873
# Epoch 1/10
# 52/52 [==============================] - 7s 42ms/step - loss: 1.1739 - accuracy: 0.4875 - val_loss: 0.9357 - val_accuracy: 0.6186
# Epoch 2/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.6369 - accuracy: 0.7621 - val_loss: 0.8904 - val_accuracy: 0.6701
# Epoch 3/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5488 - accuracy: 0.8003 - val_loss: 0.8602 - val_accuracy: 0.6770
# Epoch 4/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5263 - accuracy: 0.8109 - val_loss: 0.8829 - val_accuracy: 0.6873
# Epoch 5/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.5002 - accuracy: 0.8215 - val_loss: 0.8737 - val_accuracy: 0.6804
# Epoch 6/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.4709 - accuracy: 0.8437 - val_loss: 0.8726 - val_accuracy: 0.6838
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8829 - accuracy: 0.6873
# Loss Score :  0.8829 Accuracy Score :  0.6873
# Epoch 1/10
# 52/52 [==============================] - 7s 42ms/step - loss: 1.1101 - accuracy: 0.5222 - val_loss: 0.9095 - val_accuracy: 0.6667
# Epoch 2/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.6350 - accuracy: 0.7749 - val_loss: 0.8746 - val_accuracy: 0.6770
# Epoch 3/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5512 - accuracy: 0.8052 - val_loss: 0.8839 - val_accuracy: 0.6838
# Epoch 4/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.5275 - accuracy: 0.7950 - val_loss: 0.8580 - val_accuracy: 0.6873
# Epoch 5/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5103 - accuracy: 0.8091 - val_loss: 0.9049 - val_accuracy: 0.6701
# Epoch 6/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.5013 - accuracy: 0.7990 - val_loss: 0.9340 - val_accuracy: 0.6804
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8580 - accuracy: 0.6873
# Loss Score :  0.858 Accuracy Score :  0.6873
# Epoch 1/10
# 52/52 [==============================] - 7s 42ms/step - loss: 1.2431 - accuracy: 0.4440 - val_loss: 0.8953 - val_accuracy: 0.6564
# Epoch 2/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.6295 - accuracy: 0.7827 - val_loss: 0.8720 - val_accuracy: 0.6735
# Epoch 3/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.5589 - accuracy: 0.7898 - val_loss: 0.8776 - val_accuracy: 0.6632
# Epoch 4/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5325 - accuracy: 0.7961 - val_loss: 0.8883 - val_accuracy: 0.6804
# Epoch 5/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5184 - accuracy: 0.8049 - val_loss: 0.8669 - val_accuracy: 0.6804
# Epoch 6/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5199 - accuracy: 0.8069 - val_loss: 0.8805 - val_accuracy: 0.6701
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8883 - accuracy: 0.6804
# Loss Score :  0.8883 Accuracy Score :  0.6804
# Epoch 1/10
# 52/52 [==============================] - 7s 40ms/step - loss: 1.0673 - accuracy: 0.5451 - val_loss: 0.9432 - val_accuracy: 0.6460
# Epoch 2/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.6629 - accuracy: 0.7574 - val_loss: 0.8789 - val_accuracy: 0.6667
# Epoch 3/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.5630 - accuracy: 0.7918 - val_loss: 0.8770 - val_accuracy: 0.6735
# Epoch 4/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.5566 - accuracy: 0.7995 - val_loss: 0.8703 - val_accuracy: 0.6873
# Epoch 5/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.4888 - accuracy: 0.8280 - val_loss: 0.8748 - val_accuracy: 0.6907
# Epoch 6/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.5136 - accuracy: 0.8198 - val_loss: 0.8633 - val_accuracy: 0.6873
# Epoch 7/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.4851 - accuracy: 0.8230 - val_loss: 0.8749 - val_accuracy: 0.6942
# Epoch 8/10
# 52/52 [==============================] - 1s 10ms/step - loss: 0.4556 - accuracy: 0.8274 - val_loss: 0.8687 - val_accuracy: 0.6838
# Epoch 9/10
# 52/52 [==============================] - 1s 11ms/step - loss: 0.5151 - accuracy: 0.8139 - val_loss: 0.8990 - val_accuracy: 0.6701
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8749 - accuracy: 0.6942
# Loss Score :  0.8749 Accuracy Score :  0.6942

# %%
classification_model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8749 - accuracy: 0.6942
# [0.8749446868896484, 0.6941580772399902]

# %%
pred = classification_model.predict(X_test)
y_pred = encoder_cakapan_2.inverse_transform(pred)
y_true = encoder_cakapan_2.inverse_transform(y_test)
print(classification_report(y_true, y_pred, digits=4))
print(confusion_matrix(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Marah     0.6735    0.7857    0.7253        42
#        Sedih     0.6914    0.6512    0.6707        86
#       Senang     0.7120    0.7876    0.7479       113
#     Terkejut     0.6667    0.4800    0.5581        50
#
#     accuracy                         0.6942       291
#    macro avg     0.6859    0.6761    0.6755       291
# weighted avg     0.6925    0.6942    0.6892       291
#
# [[33  5  2  2]
#  [ 7 56 20  3]
#  [ 5 12 89  7]
#  [ 4  8 14 24]]

# %%
classification_model.save(drive_dir + "/Eksperimen/Model/model_leksikal_bertahap_classification_4.h5")
