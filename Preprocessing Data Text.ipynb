# %% [markdown]
# # Preprocessing Data Textual - Pembangunan Model Emosi

# %% [markdown]
# ## Library Preparation

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading https://files.pythonhosted.org/packages/6f/4b/bab676953da3103003730b8fcdfadbdd20f333d4add10af949dd5c51e6ed/Sastrawi-1.0.1-py2.py3-none-any.whl (209kB)
#      |████████████████████████████████| 215kB 8.7MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
import requests
import os
import joblib
import pandas as pd
from google.colab import drive
from google.colab import files
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
drive.mount('/content/gdrive')
drive_dir = "/content/gdrive/MyDrive/Teknik Informatika/Semester 7/TUGAS AKHIR/TA 2"
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Preprocess Data

# %%
def remove_unknown_tag(text):
    text = text.replace("<unk>","")
    return text

def remove_noise_tag(text):
    text = text.replace("<noise>","")
    return text

def remove_language_tag(text):
    text = text.replace("<eng>","")
    text = text.replace("</eng>","")
    text = text.replace("<arab>","")
    text = text.replace("</arab>","")
    text = text.replace("<jawa>","")
    text = text.replace("</jawa>","")
    return text

def remove_tag(text):
    text = text.replace("<","")
    text = text.replace(">","")
    return text

def word_normalization(text):
    headers = {'x-api-key': 'G9c0AssPEjGQD7Qo0q8IIJKUG9GmoHz8dEcSRner', 'Content-Type': 'application/json'}
    body = {'text': text}
    r_pos = requests.post('https://api.prosa.ai/v1/normals', headers = headers, json = body)
    return r_pos.json()['text']

def stemming(text):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    return stemmer.stem(text)

def remove_stop_word(text):
  factory = StopWordRemoverFactory()
  stopword = factory.create_stop_word_remover()
  return stopword.remove(text)

# %% [markdown]
# ### Basic Preprocess

# %%
def preprocess(text):
    text = remove_unknown_tag(text)
    text = remove_noise_tag(text)
    text = remove_language_tag(text)
    text = remove_tag(text)
    return text

# %%
data = joblib.load(drive_dir + "/Eksperimen/Data/raw.pkl")
texts = data["Transkripsi"]

# %%
processed = []
i = 0
for text in texts:
    if i % 100 == 0: print("Preprocessing...", i, "data text already done.")
    processed.append(preprocess(text))
    i = i + 1
# Out:
# Preprocessing... 0 data text already done.
# Preprocessing... 100 data text already done.
# Preprocessing... 200 data text already done.
# Preprocessing... 300 data text already done.
# Preprocessing... 400 data text already done.
# Preprocessing... 500 data text already done.
# Preprocessing... 600 data text already done.
# Preprocessing... 700 data text already done.
# Preprocessing... 800 data text already done.
# Preprocessing... 900 data text already done.
# Preprocessing... 1000 data text already done.
# Preprocessing... 1100 data text already done.
# Preprocessing... 1200 data text already done.
# Preprocessing... 1300 data text already done.
# Preprocessing... 1400 data text already done.
# Preprocessing... 1500 data text already done.
# Preprocessing... 1600 data text already done.
# Preprocessing... 1700 data text already done.
# Preprocessing... 1800 data text already done.
# Preprocessing... 1900 data text already done.
# Preprocessing... 2000 data text already done.
# Preprocessing... 2100 data text already done.
# Preprocessing... 2200 data text already done.
# Preprocessing... 2300 data text already done.
# Preprocessing... 2400 data text already done.
# Preprocessing... 2500 data text already done.
# Preprocessing... 2600 data text already done.
# Preprocessing... 2700 data text already done.
# Preprocessing... 2800 data text already done.
# Preprocessing... 2900 data text already done.
# Preprocessing... 3000 data text already done.
# Preprocessing... 3100 data text already done.
# Preprocessing... 3200 data text already done.
# Preprocessing... 3300 data text already done.
# Preprocessing... 3400 data text already done.
# Preprocessing... 3500 data text already done.
# Preprocessing... 3600 data text already done.
# Preprocessing... 3700 data text already done.
# Preprocessing... 3800 data text already done.
# Preprocessing... 3900 data text already done.
# Preprocessing... 4000 data text already done.
# Preprocessing... 4100 data text already done.
# Preprocessing... 4200 data text already done.
# Preprocessing... 4300 data text already done.
# Preprocessing... 4400 data text already done.
# Preprocessing... 4500 data text already done.
# Preprocessing... 4600 data text already done.
# Preprocessing... 4700 data text already done.
# Preprocessing... 4800 data text already done.
# Preprocessing... 4900 data text already done.
# Preprocessing... 5000 data text already done.
# Preprocessing... 5100 data text already done.
# Preprocessing... 5200 data text already done.
# Preprocessing... 5300 data text already done.
# Preprocessing... 5400 data text already done.
# Preprocessing... 5500 data text already done.
# Preprocessing... 5600 data text already done.
# Preprocessing... 5700 data text already done.
# Preprocessing... 5800 data text already done.
# Preprocessing... 5900 data text already done.
# Preprocessing... 6000 data text already done.
# Preprocessing... 6100 data text already done.
# Preprocessing... 6200 data text already done.
# Preprocessing... 6300 data text already done.
# Preprocessing... 6400 data text already done.
# Preprocessing... 6500 data text already done.
# Preprocessing... 6600 data text already done.
# Preprocessing... 6700 data text already done.
# Preprocessing... 6800 data text already done.
# Preprocessing... 6900 data text already done.
# Preprocessing... 7000 data text already done.
# Preprocessing... 7100 data text already done.
# Preprocessing... 7200 data text already done.
# Preprocessing... 7300 data text already done.
# Preprocessing... 7400 data text already done.
# Preprocessing... 7500 data text already done.
# Preprocessing... 7600 data text already done.
# Preprocessing... 7700 data text already done.
# Preprocessing... 7800 data text already done.
# Preprocessing... 7900 data text already done.
# Preprocessing... 8000 data text already done.
# Preprocessing... 8100 data text already done.
# Preprocessing... 8200 data text already done.
# Preprocessing... 8300 data text already done.
# Preprocessing... 8400 data text already done.
# Preprocessing... 8500 data text already done.
# Preprocessing... 8600 data text already done.
# Preprocessing... 8700 data text already done.
# Preprocessing... 8800 data text already done.
# Preprocessing... 8900 data text already done.
# Preprocessing... 9000 data text already done.
# Preprocessing... 9100 data text already done.
# Preprocessing... 9200 data text already done.
# Preprocessing... 9300 data text already done.
# Preprocessing... 9400 data text already done.
# Preprocessing... 9500 data text already done.
# Preprocessing... 9600 data text already done.
# Preprocessing... 9700 data text already done.
# Preprocessing... 9800 data text already done.
# Preprocessing... 9900 data text already done.
# Preprocessing... 10000 data text already done.
# Preprocessing... 10100 data text already done.
# Preprocessing... 10200 data text already done.
# Preprocessing... 10300 data text already done.
# Preprocessing... 10400 data text already done.
# Preprocessing... 10500 data text already done.
# Preprocessing... 10600 data text already done.
# Preprocessing... 10700 data text already done.
# Preprocessing... 10800 data text already done.

# %%
processed_data = data.copy()
processed_data['Transkripsi'] = processed
processed_data = processed_data.sort_values(by=['ID Ucapan'])
processed_data = processed_data.reset_index()
processed_data = processed_data.drop(columns=['index'])
processed_data.head()
# Out:
#    ID Ucapan  ... Abstraksi Emosi
# 0  001001001  ...          Senang
# 1  001001002  ...             NaN
# 2  001001003  ...             NaN
# 3  001001004  ...             NaN
# 4  001001005  ...             NaN
#
# [5 rows x 4 columns]

# %%
processed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10822 entries, 0 to 10821
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID Ucapan        10822 non-null  object
#  1   Transkripsi      10822 non-null  object
#  2   Label Emosi      10822 non-null  object
#  3   Abstraksi Emosi  2003 non-null   object
# dtypes: object(4)
# memory usage: 338.3+ KB

# %%
vocab = []
for text in processed_data['Transkripsi']:
  for word in text.split():
    vocab.append(word)
vocab = set(vocab)
print("Total kata : ", len(vocab))
# Out:
# Total kata :  8714

# %%
joblib.dump(processed_data, "basic.pkl")
files.download("basic.pkl")

# %% [markdown]
# ### + Word Normalization

# %%
def preprocess(text):
    word_normalization(text)
    return text

# %%
data = joblib.load(drive_dir + "/Eksperimen/Data/basic.pkl")
texts = data["Transkripsi"]

# %%
processed = []
i = 0
for text in texts:
    if i % 100 == 0: print("Preprocessing...", i, "data text already done.")
    processed.append(preprocess(text))
    i = i + 1

# %%
processed_data = data.copy()
processed_data['Transkripsi'] = processed
processed_data = processed_data.sort_values(by=['ID Ucapan'])
processed_data = processed_data.reset_index()
processed_data = processed_data.drop(columns=['index'])
processed_data.head()
# Out:
#    ID Ucapan  ... Abstraksi Emosi
# 0  001001001  ...          Senang
# 1  001001002  ...             NaN
# 2  001001003  ...             NaN
# 3  001001004  ...             NaN
# 4  001001005  ...             NaN
#
# [5 rows x 4 columns]

# %%
processed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10822 entries, 0 to 10821
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID Ucapan        10822 non-null  object
#  1   Transkripsi      10822 non-null  object
#  2   Label Emosi      10822 non-null  object
#  3   Abstraksi Emosi  2003 non-null   object
# dtypes: object(4)
# memory usage: 338.3+ KB

# %%
vocab = []
for text in processed_data['Transkripsi']:
  for word in text.split():
    vocab.append(word)
vocab = set(vocab)
print("Total kata : ", len(vocab))
# Out:
# Total kata :  8714

# %%
joblib.dump(processed_data, "normalization.pkl")
files.download("normalization.pkl")

# %% [markdown]
# ### + Stemming

# %%
def preprocess(text):
    text = stemming(text)
    return text

# %%
data = joblib.load(drive_dir + "/Eksperimen/Data/normalization.pkl")
texts = data["Transkripsi"]

# %%
processed = []
i = 0
for text in texts:
    if i % 100 == 0: print("Preprocessing...", i, "data text already done.")
    processed.append(preprocess(text))
    i = i + 1
# Out:
# Preprocessing... 0 data text already done.
# Preprocessing... 100 data text already done.
# Preprocessing... 200 data text already done.
# Preprocessing... 300 data text already done.
# Preprocessing... 400 data text already done.
# Preprocessing... 500 data text already done.
# Preprocessing... 600 data text already done.
# Preprocessing... 700 data text already done.
# Preprocessing... 800 data text already done.
# Preprocessing... 900 data text already done.
# Preprocessing... 1000 data text already done.
# Preprocessing... 1100 data text already done.
# Preprocessing... 1200 data text already done.
# Preprocessing... 1300 data text already done.
# Preprocessing... 1400 data text already done.
# Preprocessing... 1500 data text already done.
# Preprocessing... 1600 data text already done.
# Preprocessing... 1700 data text already done.
# Preprocessing... 1800 data text already done.
# Preprocessing... 1900 data text already done.
# Preprocessing... 2000 data text already done.
# Preprocessing... 2100 data text already done.
# Preprocessing... 2200 data text already done.
# Preprocessing... 2300 data text already done.
# Preprocessing... 2400 data text already done.
# Preprocessing... 2500 data text already done.
# Preprocessing... 2600 data text already done.
# Preprocessing... 2700 data text already done.
# Preprocessing... 2800 data text already done.
# Preprocessing... 2900 data text already done.
# Preprocessing... 3000 data text already done.
# Preprocessing... 3100 data text already done.
# Preprocessing... 3200 data text already done.
# Preprocessing... 3300 data text already done.
# Preprocessing... 3400 data text already done.
# Preprocessing... 3500 data text already done.
# Preprocessing... 3600 data text already done.
# Preprocessing... 3700 data text already done.
# Preprocessing... 3800 data text already done.
# Preprocessing... 3900 data text already done.
# Preprocessing... 4000 data text already done.
# Preprocessing... 4100 data text already done.
# Preprocessing... 4200 data text already done.
# Preprocessing... 4300 data text already done.
# Preprocessing... 4400 data text already done.
# Preprocessing... 4500 data text already done.
# Preprocessing... 4600 data text already done.
# Preprocessing... 4700 data text already done.
# Preprocessing... 4800 data text already done.
# Preprocessing... 4900 data text already done.
# Preprocessing... 5000 data text already done.
# Preprocessing... 5100 data text already done.
# Preprocessing... 5200 data text already done.
# Preprocessing... 5300 data text already done.
# Preprocessing... 5400 data text already done.
# Preprocessing... 5500 data text already done.
# Preprocessing... 5600 data text already done.
# Preprocessing... 5700 data text already done.
# Preprocessing... 5800 data text already done.
# Preprocessing... 5900 data text already done.
# Preprocessing... 6000 data text already done.
# Preprocessing... 6100 data text already done.
# Preprocessing... 6200 data text already done.
# Preprocessing... 6300 data text already done.
# Preprocessing... 6400 data text already done.
# Preprocessing... 6500 data text already done.
# Preprocessing... 6600 data text already done.
# Preprocessing... 6700 data text already done.
# Preprocessing... 6800 data text already done.
# Preprocessing... 6900 data text already done.
# Preprocessing... 7000 data text already done.
# Preprocessing... 7100 data text already done.
# Preprocessing... 7200 data text already done.
# Preprocessing... 7300 data text already done.
# Preprocessing... 7400 data text already done.
# Preprocessing... 7500 data text already done.
# Preprocessing... 7600 data text already done.
# Preprocessing... 7700 data text already done.
# Preprocessing... 7800 data text already done.
# Preprocessing... 7900 data text already done.
# Preprocessing... 8000 data text already done.
# Preprocessing... 8100 data text already done.
# Preprocessing... 8200 data text already done.
# Preprocessing... 8300 data text already done.
# Preprocessing... 8400 data text already done.
# Preprocessing... 8500 data text already done.
# Preprocessing... 8600 data text already done.
# Preprocessing... 8700 data text already done.
# Preprocessing... 8800 data text already done.
# Preprocessing... 8900 data text already done.
# Preprocessing... 9000 data text already done.
# Preprocessing... 9100 data text already done.
# Preprocessing... 9200 data text already done.
# Preprocessing... 9300 data text already done.
# Preprocessing... 9400 data text already done.
# Preprocessing... 9500 data text already done.
# Preprocessing... 9600 data text already done.
# Preprocessing... 9700 data text already done.
# Preprocessing... 9800 data text already done.
# Preprocessing... 9900 data text already done.
# Preprocessing... 10000 data text already done.
# Preprocessing... 10100 data text already done.
# Preprocessing... 10200 data text already done.
# Preprocessing... 10300 data text already done.
# Preprocessing... 10400 data text already done.
# Preprocessing... 10500 data text already done.
# Preprocessing... 10600 data text already done.
# Preprocessing... 10700 data text already done.
# Preprocessing... 10800 data text already done.

# %%
processed_data = data.copy()
processed_data['Transkripsi'] = processed
processed_data = processed_data.sort_values(by=['ID Ucapan'])
processed_data = processed_data.reset_index()
processed_data = processed_data.drop(columns=['index'])
processed_data.head()
# Out:
#    ID Ucapan  ... Abstraksi Emosi
# 0  001001001  ...          Senang
# 1  001001002  ...             NaN
# 2  001001003  ...             NaN
# 3  001001004  ...             NaN
# 4  001001005  ...             NaN
#
# [5 rows x 4 columns]

# %%
processed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10822 entries, 0 to 10821
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID Ucapan        10822 non-null  object
#  1   Transkripsi      10822 non-null  object
#  2   Label Emosi      10822 non-null  object
#  3   Abstraksi Emosi  2003 non-null   object
# dtypes: object(4)
# memory usage: 338.3+ KB

# %%
vocab = []
for text in processed_data['Transkripsi']:
  for word in text.split():
    vocab.append(word)
vocab = set(vocab)
print("Total kata : ", len(vocab))
# Out:
# Total kata :  5054

# %%
joblib.dump(processed_data, "stemming.pkl")
files.download("stemming.pkl")

# %% [markdown]
# ### + Stop Word Elimination

# %%
remove_stop_word('Dengan Menggunakan Python dan Library Sastrawi saya dapat melakukan proses Stopword Removal')
# Out:
# 'Dengan Menggunakan Python Library Sastrawi dapat melakukan proses Stopword Removal'

# %%
def preprocess(text):
    text = remove_stop_word(text)
    return text

# %%
data = joblib.load(drive_dir + "/Eksperimen/Data/stemming.pkl")
texts = data["Transkripsi"]

# %%
processed = []
i = 0
for text in texts:
    if i % 100 == 0: print("Preprocessing...", i, "data text already done.")
    processed.append(preprocess(text))
    i = i + 1
# Out:
# Preprocessing... 0 data text already done.
# Preprocessing... 100 data text already done.
# Preprocessing... 200 data text already done.
# Preprocessing... 300 data text already done.
# Preprocessing... 400 data text already done.
# Preprocessing... 500 data text already done.
# Preprocessing... 600 data text already done.
# Preprocessing... 700 data text already done.
# Preprocessing... 800 data text already done.
# Preprocessing... 900 data text already done.
# Preprocessing... 1000 data text already done.
# Preprocessing... 1100 data text already done.
# Preprocessing... 1200 data text already done.
# Preprocessing... 1300 data text already done.
# Preprocessing... 1400 data text already done.
# Preprocessing... 1500 data text already done.
# Preprocessing... 1600 data text already done.
# Preprocessing... 1700 data text already done.
# Preprocessing... 1800 data text already done.
# Preprocessing... 1900 data text already done.
# Preprocessing... 2000 data text already done.
# Preprocessing... 2100 data text already done.
# Preprocessing... 2200 data text already done.
# Preprocessing... 2300 data text already done.
# Preprocessing... 2400 data text already done.
# Preprocessing... 2500 data text already done.
# Preprocessing... 2600 data text already done.
# Preprocessing... 2700 data text already done.
# Preprocessing... 2800 data text already done.
# Preprocessing... 2900 data text already done.
# Preprocessing... 3000 data text already done.
# Preprocessing... 3100 data text already done.
# Preprocessing... 3200 data text already done.
# Preprocessing... 3300 data text already done.
# Preprocessing... 3400 data text already done.
# Preprocessing... 3500 data text already done.
# Preprocessing... 3600 data text already done.
# Preprocessing... 3700 data text already done.
# Preprocessing... 3800 data text already done.
# Preprocessing... 3900 data text already done.
# Preprocessing... 4000 data text already done.
# Preprocessing... 4100 data text already done.
# Preprocessing... 4200 data text already done.
# Preprocessing... 4300 data text already done.
# Preprocessing... 4400 data text already done.
# Preprocessing... 4500 data text already done.
# Preprocessing... 4600 data text already done.
# Preprocessing... 4700 data text already done.
# Preprocessing... 4800 data text already done.
# Preprocessing... 4900 data text already done.
# Preprocessing... 5000 data text already done.
# Preprocessing... 5100 data text already done.
# Preprocessing... 5200 data text already done.
# Preprocessing... 5300 data text already done.
# Preprocessing... 5400 data text already done.
# Preprocessing... 5500 data text already done.
# Preprocessing... 5600 data text already done.
# Preprocessing... 5700 data text already done.
# Preprocessing... 5800 data text already done.
# Preprocessing... 5900 data text already done.
# Preprocessing... 6000 data text already done.
# Preprocessing... 6100 data text already done.
# Preprocessing... 6200 data text already done.
# Preprocessing... 6300 data text already done.
# Preprocessing... 6400 data text already done.
# Preprocessing... 6500 data text already done.
# Preprocessing... 6600 data text already done.
# Preprocessing... 6700 data text already done.
# Preprocessing... 6800 data text already done.
# Preprocessing... 6900 data text already done.
# Preprocessing... 7000 data text already done.
# Preprocessing... 7100 data text already done.
# Preprocessing... 7200 data text already done.
# Preprocessing... 7300 data text already done.
# Preprocessing... 7400 data text already done.
# Preprocessing... 7500 data text already done.
# Preprocessing... 7600 data text already done.
# Preprocessing... 7700 data text already done.
# Preprocessing... 7800 data text already done.
# Preprocessing... 7900 data text already done.
# Preprocessing... 8000 data text already done.
# Preprocessing... 8100 data text already done.
# Preprocessing... 8200 data text already done.
# Preprocessing... 8300 data text already done.
# Preprocessing... 8400 data text already done.
# Preprocessing... 8500 data text already done.
# Preprocessing... 8600 data text already done.
# Preprocessing... 8700 data text already done.
# Preprocessing... 8800 data text already done.
# Preprocessing... 8900 data text already done.
# Preprocessing... 9000 data text already done.
# Preprocessing... 9100 data text already done.
# Preprocessing... 9200 data text already done.
# Preprocessing... 9300 data text already done.
# Preprocessing... 9400 data text already done.
# Preprocessing... 9500 data text already done.
# Preprocessing... 9600 data text already done.
# Preprocessing... 9700 data text already done.
# Preprocessing... 9800 data text already done.
# Preprocessing... 9900 data text already done.
# Preprocessing... 10000 data text already done.
# Preprocessing... 10100 data text already done.
# Preprocessing... 10200 data text already done.
# Preprocessing... 10300 data text already done.
# Preprocessing... 10400 data text already done.
# Preprocessing... 10500 data text already done.
# Preprocessing... 10600 data text already done.
# Preprocessing... 10700 data text already done.
# Preprocessing... 10800 data text already done.

# %%
processed_data = data.copy()
processed_data['Transkripsi'] = processed
processed_data = processed_data.sort_values(by=['ID Ucapan'])
processed_data = processed_data.reset_index()
processed_data = processed_data.drop(columns=['index'])
processed_data.head()
# Out:
#    ID Ucapan  ... Abstraksi Emosi
# 0  001001001  ...          Senang
# 1  001001002  ...             NaN
# 2  001001003  ...             NaN
# 3  001001004  ...             NaN
# 4  001001005  ...             NaN
#
# [5 rows x 4 columns]

# %%
processed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10822 entries, 0 to 10821
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID Ucapan        10822 non-null  object
#  1   Transkripsi      10822 non-null  object
#  2   Label Emosi      10822 non-null  object
#  3   Abstraksi Emosi  2003 non-null   object
# dtypes: object(4)
# memory usage: 338.3+ KB

# %%
vocab = []
for text in processed_data['Transkripsi']:
  for word in text.split():
    vocab.append(word)
vocab = set(vocab)
print("Total kata : ", len(vocab))
# Out:
# Total kata :  5046

# %%
joblib.dump(processed_data, "stopword.pkl")
files.download("stopword.pkl")

# %% [markdown]
# ### InaNLP

# %%
processed_data_textual = []
i = 0
for text in data_textual['Transkripsi']:
    print("Preprocessing...", i, "data text already done.")
    processed_data_textual.append(preprocess(text))
    i = i + 1

# %%
for text in data_textual['Transkripsi'][4570:]:
    print("Preprocessing...", i, "data text already done.")
    processed_data_textual.append(preprocess(text))
    i = i + 1

# %%
for text in data_textual['Transkripsi'][5941:]:
    print("Preprocessing...", i, "data text already done.")
    processed_data_textual.append(preprocess(text))
    i = i + 1
# Out:
# Preprocessing... 5941 data text already done.
# Preprocessing... 5942 data text already done.
# Preprocessing... 5943 data text already done.
# Preprocessing... 5944 data text already done.
# Preprocessing... 5945 data text already done.
# Preprocessing... 5946 data text already done.
# Preprocessing... 5947 data text already done.
# Preprocessing... 5948 data text already done.
# Preprocessing... 5949 data text already done.
# Preprocessing... 5950 data text already done.
# Preprocessing... 5951 data text already done.
# Preprocessing... 5952 data text already done.
# Preprocessing... 5953 data text already done.
# Preprocessing... 5954 data text already done.
# Preprocessing... 5955 data text already done.
# Preprocessing... 5956 data text already done.
# Preprocessing... 5957 data text already done.
# Preprocessing... 5958 data text already done.
# Preprocessing... 5959 data text already done.
# Preprocessing... 5960 data text already done.
# Preprocessing... 5961 data text already done.
# Preprocessing... 5962 data text already done.
# Preprocessing... 5963 data text already done.
# Preprocessing... 5964 data text already done.
# Preprocessing... 5965 data text already done.
# Preprocessing... 5966 data text already done.
# Preprocessing... 5967 data text already done.
# Preprocessing... 5968 data text already done.
# Preprocessing... 5969 data text already done.
# Preprocessing... 5970 data text already done.
# Preprocessing... 5971 data text already done.
# Preprocessing... 5972 data text already done.
# Preprocessing... 5973 data text already done.
# Preprocessing... 5974 data text already done.
# Preprocessing... 5975 data text already done.
# Preprocessing... 5976 data text already done.
# Preprocessing... 5977 data text already done.
# Preprocessing... 5978 data text already done.
# Preprocessing... 5979 data text already done.
# Preprocessing... 5980 data text already done.
# Preprocessing... 5981 data text already done.
# Preprocessing... 5982 data text already done.
# Preprocessing... 5983 data text already done.
# Preprocessing... 5984 data text already done.
# Preprocessing... 5985 data text already done.
# Preprocessing... 5986 data text already done.
# Preprocessing... 5987 data text already done.
# Preprocessing... 5988 data text already done.
# Preprocessing... 5989 data text already done.
# Preprocessing... 5990 data text already done.
# Preprocessing... 5991 data text already done.
# Preprocessing... 5992 data text already done.
# Preprocessing... 5993 data text already done.
# Preprocessing... 5994 data text already done.
# Preprocessing... 5995 data text already done.
# Preprocessing... 5996 data text already done.
# Preprocessing... 5997 data text already done.
# Preprocessing... 5998 data text already done.
# Preprocessing... 5999 data text already done.
# Preprocessing... 6000 data text already done.
# Preprocessing... 6001 data text already done.
# Preprocessing... 6002 data text already done.
# Preprocessing... 6003 data text already done.
# Preprocessing... 6004 data text already done.
# Preprocessing... 6005 data text already done.
# Preprocessing... 6006 data text already done.
# Preprocessing... 6007 data text already done.
# Preprocessing... 6008 data text already done.
# Preprocessing... 6009 data text already done.
# Preprocessing... 6010 data text already done.
# Preprocessing... 6011 data text already done.
# Preprocessing... 6012 data text already done.
# Preprocessing... 6013 data text already done.
# Preprocessing... 6014 data text already done.
# Preprocessing... 6015 data text already done.
# Preprocessing... 6016 data text already done.
# Preprocessing... 6017 data text already done.
# Preprocessing... 6018 data text already done.
# Preprocessing... 6019 data text already done.
# Preprocessing... 6020 data text already done.
# Preprocessing... 6021 data text already done.
# Preprocessing... 6022 data text already done.
# Preprocessing... 6023 data text already done.
# Preprocessing... 6024 data text already done.
# Preprocessing... 6025 data text already done.
# Preprocessing... 6026 data text already done.
# Preprocessing... 6027 data text already done.
# Preprocessing... 6028 data text already done.
# Preprocessing... 6029 data text already done.
# Preprocessing... 6030 data text already done.
# Preprocessing... 6031 data text already done.
# Preprocessing... 6032 data text already done.
# Preprocessing... 6033 data text already done.
# Preprocessing... 6034 data text already done.
# Preprocessing... 6035 data text already done.
# Preprocessing... 6036 data text already done.
# Preprocessing... 6037 data text already done.
# Preprocessing... 6038 data text already done.
# Preprocessing... 6039 data text already done.
# Preprocessing... 6040 data text already done.
# Preprocessing... 6041 data text already done.
# Preprocessing... 6042 data text already done.
# Preprocessing... 6043 data text already done.
# Preprocessing... 6044 data text already done.
# Preprocessing... 6045 data text already done.
# Preprocessing... 6046 data text already done.
# Preprocessing... 6047 data text already done.
# Preprocessing... 6048 data text already done.
# Preprocessing... 6049 data text already done.
# Preprocessing... 6050 data text already done.
# Preprocessing... 6051 data text already done.
# Preprocessing... 6052 data text already done.
# Preprocessing... 6053 data text already done.
# Preprocessing... 6054 data text already done.
# Preprocessing... 6055 data text already done.
# Preprocessing... 6056 data text already done.
# Preprocessing... 6057 data text already done.
# Preprocessing... 6058 data text already done.
# Preprocessing... 6059 data text already done.
# Preprocessing... 6060 data text already done.
# Preprocessing... 6061 data text already done.
# Preprocessing... 6062 data text already done.
# Preprocessing... 6063 data text already done.
# Preprocessing... 6064 data text already done.
# Preprocessing... 6065 data text already done.
# Preprocessing... 6066 data text already done.
# Preprocessing... 6067 data text already done.
# Preprocessing... 6068 data text already done.
# Preprocessing... 6069 data text already done.
# Preprocessing... 6070 data text already done.
# Preprocessing... 6071 data text already done.
# Preprocessing... 6072 data text already done.
# Preprocessing... 6073 data text already done.
# Preprocessing... 6074 data text already done.
# Preprocessing... 6075 data text already done.
# Preprocessing... 6076 data text already done.
# Preprocessing... 6077 data text already done.
# Preprocessing... 6078 data text already done.
# Preprocessing... 6079 data text already done.
# Preprocessing... 6080 data text already done.
# Preprocessing... 6081 data text already done.
# Preprocessing... 6082 data text already done.
# Preprocessing... 6083 data text already done.
# Preprocessing... 6084 data text already done.
# Preprocessing... 6085 data text already done.
# Preprocessing... 6086 data text already done.
# Preprocessing... 6087 data text already done.
# Preprocessing... 6088 data text already done.
# Preprocessing... 6089 data text already done.
# Preprocessing... 6090 data text already done.
# Preprocessing... 6091 data text already done.
# Preprocessing... 6092 data text already done.
# Preprocessing... 6093 data text already done.
# Preprocessing... 6094 data text already done.
# Preprocessing... 6095 data text already done.
# Preprocessing... 6096 data text already done.
# Preprocessing... 6097 data text already done.
# Preprocessing... 6098 data text already done.
# Preprocessing... 6099 data text already done.
# Preprocessing... 6100 data text already done.
# Preprocessing... 6101 data text already done.
# Preprocessing... 6102 data text already done.
# Preprocessing... 6103 data text already done.
# Preprocessing... 6104 data text already done.
# Preprocessing... 6105 data text already done.
# Preprocessing... 6106 data text already done.
# Preprocessing... 6107 data text already done.
# Preprocessing... 6108 data text already done.
# Preprocessing... 6109 data text already done.
# Preprocessing... 6110 data text already done.
# Preprocessing... 6111 data text already done.
# Preprocessing... 6112 data text already done.
# Preprocessing... 6113 data text already done.
# Preprocessing... 6114 data text already done.
# Preprocessing... 6115 data text already done.
# Preprocessing... 6116 data text already done.
# Preprocessing... 6117 data text already done.
# Preprocessing... 6118 data text already done.
# Preprocessing... 6119 data text already done.
# Preprocessing... 6120 data text already done.
# Preprocessing... 6121 data text already done.
# Preprocessing... 6122 data text already done.
# Preprocessing... 6123 data text already done.
# Preprocessing... 6124 data text already done.
# Preprocessing... 6125 data text already done.
# Preprocessing... 6126 data text already done.
# Preprocessing... 6127 data text already done.
# Preprocessing... 6128 data text already done.
# Preprocessing... 6129 data text already done.
# Preprocessing... 6130 data text already done.
# Preprocessing... 6131 data text already done.
# Preprocessing... 6132 data text already done.
# Preprocessing... 6133 data text already done.
# Preprocessing... 6134 data text already done.
# Preprocessing... 6135 data text already done.
# Preprocessing... 6136 data text already done.
# Preprocessing... 6137 data text already done.
# Preprocessing... 6138 data text already done.
# Preprocessing... 6139 data text already done.
# Preprocessing... 6140 data text already done.
# Preprocessing... 6141 data text already done.
# Preprocessing... 6142 data text already done.
# Preprocessing... 6143 data text already done.
# Preprocessing... 6144 data text already done.
# Preprocessing... 6145 data text already done.
# Preprocessing... 6146 data text already done.
# Preprocessing... 6147 data text already done.
# Preprocessing... 6148 data text already done.
# Preprocessing... 6149 data text already done.
# Preprocessing... 6150 data text already done.
# Preprocessing... 6151 data text already done.
# Preprocessing... 6152 data text already done.
# Preprocessing... 6153 data text already done.
# Preprocessing... 6154 data text already done.
# Preprocessing... 6155 data text already done.
# Preprocessing... 6156 data text already done.
# Preprocessing... 6157 data text already done.
# Preprocessing... 6158 data text already done.
# Preprocessing... 6159 data text already done.
# Preprocessing... 6160 data text already done.
# Preprocessing... 6161 data text already done.
# Preprocessing... 6162 data text already done.
# Preprocessing... 6163 data text already done.
# Preprocessing... 6164 data text already done.
# Preprocessing... 6165 data text already done.
# Preprocessing... 6166 data text already done.
# Preprocessing... 6167 data text already done.
# Preprocessing... 6168 data text already done.
# Preprocessing... 6169 data text already done.
# Preprocessing... 6170 data text already done.
# Preprocessing... 6171 data text already done.
# Preprocessing... 6172 data text already done.
# Preprocessing... 6173 data text already done.
# Preprocessing... 6174 data text already done.
# Preprocessing... 6175 data text already done.
# Preprocessing... 6176 data text already done.
# Preprocessing... 6177 data text already done.
# Preprocessing... 6178 data text already done.
# Preprocessing... 6179 data text already done.
# Preprocessing... 6180 data text already done.
# Preprocessing... 6181 data text already done.
# Preprocessing... 6182 data text already done.
# Preprocessing... 6183 data text already done.
# Preprocessing... 6184 data text already done.
# Preprocessing... 6185 data text already done.
# Preprocessing... 6186 data text already done.
# Preprocessing... 6187 data text already done.
# Preprocessing... 6188 data text already done.
# Preprocessing... 6189 data text already done.
# Preprocessing... 6190 data text already done.
# Preprocessing... 6191 data text already done.
# Preprocessing... 6192 data text already done.
# Preprocessing... 6193 data text already done.
# Preprocessing... 6194 data text already done.
# Preprocessing... 6195 data text already done.
# Preprocessing... 6196 data text already done.
# Preprocessing... 6197 data text already done.
# Preprocessing... 6198 data text already done.
# Preprocessing... 6199 data text already done.
# Preprocessing... 6200 data text already done.
# Preprocessing... 6201 data text already done.
# Preprocessing... 6202 data text already done.
# Preprocessing... 6203 data text already done.
# Preprocessing... 6204 data text already done.
# Preprocessing... 6205 data text already done.
# Preprocessing... 6206 data text already done.
# Preprocessing... 6207 data text already done.
# Preprocessing... 6208 data text already done.
# Preprocessing... 6209 data text already done.
# Preprocessing... 6210 data text already done.
# Preprocessing... 6211 data text already done.
# Preprocessing... 6212 data text already done.
# Preprocessing... 6213 data text already done.
# Preprocessing... 6214 data text already done.
# Preprocessing... 6215 data text already done.
# Preprocessing... 6216 data text already done.
# Preprocessing... 6217 data text already done.
# Preprocessing... 6218 data text already done.
# Preprocessing... 6219 data text already done.
# Preprocessing... 6220 data text already done.
# Preprocessing... 6221 data text already done.
# Preprocessing... 6222 data text already done.
# Preprocessing... 6223 data text already done.
# Preprocessing... 6224 data text already done.
# Preprocessing... 6225 data text already done.
# Preprocessing... 6226 data text already done.
# Preprocessing... 6227 data text already done.
# Preprocessing... 6228 data text already done.
# Preprocessing... 6229 data text already done.
# Preprocessing... 6230 data text already done.
# Preprocessing... 6231 data text already done.
# Preprocessing... 6232 data text already done.
# Preprocessing... 6233 data text already done.
# Preprocessing... 6234 data text already done.
# Preprocessing... 6235 data text already done.
# Preprocessing... 6236 data text already done.
# Preprocessing... 6237 data text already done.
# Preprocessing... 6238 data text already done.
# Preprocessing... 6239 data text already done.
# Preprocessing... 6240 data text already done.
# Preprocessing... 6241 data text already done.
# Preprocessing... 6242 data text already done.
# Preprocessing... 6243 data text already done.
# Preprocessing... 6244 data text already done.
# Preprocessing... 6245 data text already done.
# Preprocessing... 6246 data text already done.
# Preprocessing... 6247 data text already done.
# Preprocessing... 6248 data text already done.
# Preprocessing... 6249 data text already done.
# Preprocessing... 6250 data text already done.
# Preprocessing... 6251 data text already done.
# Preprocessing... 6252 data text already done.
# Preprocessing... 6253 data text already done.
# Preprocessing... 6254 data text already done.
# Preprocessing... 6255 data text already done.
# Preprocessing... 6256 data text already done.
# Preprocessing... 6257 data text already done.
# Preprocessing... 6258 data text already done.
# Preprocessing... 6259 data text already done.
# Preprocessing... 6260 data text already done.
# Preprocessing... 6261 data text already done.
# Preprocessing... 6262 data text already done.
# Preprocessing... 6263 data text already done.
# Preprocessing... 6264 data text already done.
# Preprocessing... 6265 data text already done.
# Preprocessing... 6266 data text already done.
# Preprocessing... 6267 data text already done.
# Preprocessing... 6268 data text already done.
# Preprocessing... 6269 data text already done.
# Preprocessing... 6270 data text already done.
# Preprocessing... 6271 data text already done.
# Preprocessing... 6272 data text already done.
# Preprocessing... 6273 data text already done.
# Preprocessing... 6274 data text already done.
# Preprocessing... 6275 data text already done.
# Preprocessing... 6276 data text already done.
# Preprocessing... 6277 data text already done.
# Preprocessing... 6278 data text already done.
# Preprocessing... 6279 data text already done.
# Preprocessing... 6280 data text already done.
# Preprocessing... 6281 data text already done.
# Preprocessing... 6282 data text already done.
# Preprocessing... 6283 data text already done.
# Preprocessing... 6284 data text already done.
# Preprocessing... 6285 data text already done.
# Preprocessing... 6286 data text already done.
# Preprocessing... 6287 data text already done.
# Preprocessing... 6288 data text already done.
# Preprocessing... 6289 data text already done.
# Preprocessing... 6290 data text already done.
# Preprocessing... 6291 data text already done.
# Preprocessing... 6292 data text already done.
# Preprocessing... 6293 data text already done.
# Preprocessing... 6294 data text already done.
# Preprocessing... 6295 data text already done.
# Preprocessing... 6296 data text already done.
# Preprocessing... 6297 data text already done.
# Preprocessing... 6298 data text already done.
# Preprocessing... 6299 data text already done.
# Preprocessing... 6300 data text already done.
# Preprocessing... 6301 data text already done.
# Preprocessing... 6302 data text already done.
# Preprocessing... 6303 data text already done.
# Preprocessing... 6304 data text already done.
# Preprocessing... 6305 data text already done.
# Preprocessing... 6306 data text already done.
# Preprocessing... 6307 data text already done.
# Preprocessing... 6308 data text already done.
# Preprocessing... 6309 data text already done.
# Preprocessing... 6310 data text already done.
# Preprocessing... 6311 data text already done.
# Preprocessing... 6312 data text already done.
# Preprocessing... 6313 data text already done.
# Preprocessing... 6314 data text already done.
# Preprocessing... 6315 data text already done.
# Preprocessing... 6316 data text already done.
# Preprocessing... 6317 data text already done.
# Preprocessing... 6318 data text already done.
# Preprocessing... 6319 data text already done.
# Preprocessing... 6320 data text already done.
# Preprocessing... 6321 data text already done.
# Preprocessing... 6322 data text already done.
# Preprocessing... 6323 data text already done.
# Preprocessing... 6324 data text already done.
# Preprocessing... 6325 data text already done.
# Preprocessing... 6326 data text already done.
# Preprocessing... 6327 data text already done.
# Preprocessing... 6328 data text already done.
# Preprocessing... 6329 data text already done.
# Preprocessing... 6330 data text already done.
# Preprocessing... 6331 data text already done.
# Preprocessing... 6332 data text already done.
# Preprocessing... 6333 data text already done.
# Preprocessing... 6334 data text already done.
# Preprocessing... 6335 data text already done.
# Preprocessing... 6336 data text already done.
# Preprocessing... 6337 data text already done.
# Preprocessing... 6338 data text already done.
# Preprocessing... 6339 data text already done.
# Preprocessing... 6340 data text already done.
# Preprocessing... 6341 data text already done.
# Preprocessing... 6342 data text already done.
# Preprocessing... 6343 data text already done.
# Preprocessing... 6344 data text already done.
# Preprocessing... 6345 data text already done.
# Preprocessing... 6346 data text already done.
# Preprocessing... 6347 data text already done.
# Preprocessing... 6348 data text already done.
# Preprocessing... 6349 data text already done.
# Preprocessing... 6350 data text already done.
# Preprocessing... 6351 data text already done.
# Preprocessing... 6352 data text already done.
# Preprocessing... 6353 data text already done.
# Preprocessing... 6354 data text already done.
# Preprocessing... 6355 data text already done.
# Preprocessing... 6356 data text already done.
# Preprocessing... 6357 data text already done.
# Preprocessing... 6358 data text already done.
# Preprocessing... 6359 data text already done.
# Preprocessing... 6360 data text already done.
# Preprocessing... 6361 data text already done.
# Preprocessing... 6362 data text already done.
# Preprocessing... 6363 data text already done.
# Preprocessing... 6364 data text already done.
# Preprocessing... 6365 data text already done.
# Preprocessing... 6366 data text already done.
# Preprocessing... 6367 data text already done.
# Preprocessing... 6368 data text already done.
# Preprocessing... 6369 data text already done.
# Preprocessing... 6370 data text already done.
# Preprocessing... 6371 data text already done.
# Preprocessing... 6372 data text already done.
# Preprocessing... 6373 data text already done.
# Preprocessing... 6374 data text already done.
# Preprocessing... 6375 data text already done.
# Preprocessing... 6376 data text already done.
# Preprocessing... 6377 data text already done.
# Preprocessing... 6378 data text already done.
# Preprocessing... 6379 data text already done.
# Preprocessing... 6380 data text already done.
# Preprocessing... 6381 data text already done.
# Preprocessing... 6382 data text already done.
# Preprocessing... 6383 data text already done.
# Preprocessing... 6384 data text already done.
# Preprocessing... 6385 data text already done.
# Preprocessing... 6386 data text already done.
# Preprocessing... 6387 data text already done.
# Preprocessing... 6388 data text already done.
# Preprocessing... 6389 data text already done.
# Preprocessing... 6390 data text already done.
# Preprocessing... 6391 data text already done.
# Preprocessing... 6392 data text already done.
# Preprocessing... 6393 data text already done.
# Preprocessing... 6394 data text already done.
# Preprocessing... 6395 data text already done.
# Preprocessing... 6396 data text already done.
# Preprocessing... 6397 data text already done.
# Preprocessing... 6398 data text already done.
# Preprocessing... 6399 data text already done.
# Preprocessing... 6400 data text already done.
# Preprocessing... 6401 data text already done.
# Preprocessing... 6402 data text already done.
# Preprocessing... 6403 data text already done.
# Preprocessing... 6404 data text already done.
# Preprocessing... 6405 data text already done.
# Preprocessing... 6406 data text already done.
# Preprocessing... 6407 data text already done.
# Preprocessing... 6408 data text already done.
# Preprocessing... 6409 data text already done.
# Preprocessing... 6410 data text already done.
# Preprocessing... 6411 data text already done.
# Preprocessing... 6412 data text already done.
# Preprocessing... 6413 data text already done.
# Preprocessing... 6414 data text already done.
# Preprocessing... 6415 data text already done.
# Preprocessing... 6416 data text already done.
# Preprocessing... 6417 data text already done.
# Preprocessing... 6418 data text already done.
# Preprocessing... 6419 data text already done.
# Preprocessing... 6420 data text already done.
# Preprocessing... 6421 data text already done.
# Preprocessing... 6422 data text already done.
# Preprocessing... 6423 data text already done.
# Preprocessing... 6424 data text already done.
# Preprocessing... 6425 data text already done.
# Preprocessing... 6426 data text already done.
# Preprocessing... 6427 data text already done.
# Preprocessing... 6428 data text already done.
# Preprocessing... 6429 data text already done.
# Preprocessing... 6430 data text already done.
# Preprocessing... 6431 data text already done.
# Preprocessing... 6432 data text already done.
# Preprocessing... 6433 data text already done.
# Preprocessing... 6434 data text already done.
# Preprocessing... 6435 data text already done.
# Preprocessing... 6436 data text already done.
# Preprocessing... 6437 data text already done.
# Preprocessing... 6438 data text already done.
# Preprocessing... 6439 data text already done.
# Preprocessing... 6440 data text already done.
# Preprocessing... 6441 data text already done.
# Preprocessing... 6442 data text already done.
# Preprocessing... 6443 data text already done.
# Preprocessing... 6444 data text already done.
# Preprocessing... 6445 data text already done.
# Preprocessing... 6446 data text already done.
# Preprocessing... 6447 data text already done.
# Preprocessing... 6448 data text already done.
# Preprocessing... 6449 data text already done.
# Preprocessing... 6450 data text already done.
# Preprocessing... 6451 data text already done.
# Preprocessing... 6452 data text already done.
# Preprocessing... 6453 data text already done.
# Preprocessing... 6454 data text already done.
# Preprocessing... 6455 data text already done.
# Preprocessing... 6456 data text already done.
# Preprocessing... 6457 data text already done.
# Preprocessing... 6458 data text already done.
# Preprocessing... 6459 data text already done.
# Preprocessing... 6460 data text already done.
# Preprocessing... 6461 data text already done.
# Preprocessing... 6462 data text already done.
# Preprocessing... 6463 data text already done.
# Preprocessing... 6464 data text already done.
# Preprocessing... 6465 data text already done.
# Preprocessing... 6466 data text already done.
# Preprocessing... 6467 data text already done.
# Preprocessing... 6468 data text already done.
# Preprocessing... 6469 data text already done.
# Preprocessing... 6470 data text already done.
# Preprocessing... 6471 data text already done.
# Preprocessing... 6472 data text already done.
# Preprocessing... 6473 data text already done.
# Preprocessing... 6474 data text already done.
# Preprocessing... 6475 data text already done.
# Preprocessing... 6476 data text already done.
# Preprocessing... 6477 data text already done.
# Preprocessing... 6478 data text already done.
# Preprocessing... 6479 data text already done.
# Preprocessing... 6480 data text already done.
# Preprocessing... 6481 data text already done.
# Preprocessing... 6482 data text already done.
# Preprocessing... 6483 data text already done.
# Preprocessing... 6484 data text already done.
# Preprocessing... 6485 data text already done.
# Preprocessing... 6486 data text already done.
# Preprocessing... 6487 data text already done.
# Preprocessing... 6488 data text already done.
# Preprocessing... 6489 data text already done.
# Preprocessing... 6490 data text already done.
# Preprocessing... 6491 data text already done.
# Preprocessing... 6492 data text already done.
# Preprocessing... 6493 data text already done.
# Preprocessing... 6494 data text already done.
# Preprocessing... 6495 data text already done.
# Preprocessing... 6496 data text already done.
# Preprocessing... 6497 data text already done.
# Preprocessing... 6498 data text already done.
# Preprocessing... 6499 data text already done.
# Preprocessing... 6500 data text already done.
# Preprocessing... 6501 data text already done.
# Preprocessing... 6502 data text already done.
# Preprocessing... 6503 data text already done.
# Preprocessing... 6504 data text already done.
# Preprocessing... 6505 data text already done.
# Preprocessing... 6506 data text already done.
# Preprocessing... 6507 data text already done.
# Preprocessing... 6508 data text already done.
# Preprocessing... 6509 data text already done.
# Preprocessing... 6510 data text already done.
# Preprocessing... 6511 data text already done.
# Preprocessing... 6512 data text already done.
# Preprocessing... 6513 data text already done.
# Preprocessing... 6514 data text already done.
# Preprocessing... 6515 data text already done.
# Preprocessing... 6516 data text already done.
# Preprocessing... 6517 data text already done.
# Preprocessing... 6518 data text already done.
# Preprocessing... 6519 data text already done.
# Preprocessing... 6520 data text already done.
# Preprocessing... 6521 data text already done.
# Preprocessing... 6522 data text already done.
# Preprocessing... 6523 data text already done.
# Preprocessing... 6524 data text already done.
# Preprocessing... 6525 data text already done.
# Preprocessing... 6526 data text already done.
# Preprocessing... 6527 data text already done.
# Preprocessing... 6528 data text already done.
# Preprocessing... 6529 data text already done.
# Preprocessing... 6530 data text already done.
# Preprocessing... 6531 data text already done.
# Preprocessing... 6532 data text already done.
# Preprocessing... 6533 data text already done.
# Preprocessing... 6534 data text already done.
# Preprocessing... 6535 data text already done.
# Preprocessing... 6536 data text already done.
# Preprocessing... 6537 data text already done.
# Preprocessing... 6538 data text already done.
# Preprocessing... 6539 data text already done.
# Preprocessing... 6540 data text already done.
# Preprocessing... 6541 data text already done.
# Preprocessing... 6542 data text already done.
# Preprocessing... 6543 data text already done.
# Preprocessing... 6544 data text already done.
# Preprocessing... 6545 data text already done.
# Preprocessing... 6546 data text already done.
# Preprocessing... 6547 data text already done.
# Preprocessing... 6548 data text already done.
# Preprocessing... 6549 data text already done.
# Preprocessing... 6550 data text already done.
# Preprocessing... 6551 data text already done.
# Preprocessing... 6552 data text already done.
# Preprocessing... 6553 data text already done.
# Preprocessing... 6554 data text already done.
# Preprocessing... 6555 data text already done.
# Preprocessing... 6556 data text already done.
# Preprocessing... 6557 data text already done.
# Preprocessing... 6558 data text already done.
# Preprocessing... 6559 data text already done.
# Preprocessing... 6560 data text already done.
# Preprocessing... 6561 data text already done.
# Preprocessing... 6562 data text already done.
# Preprocessing... 6563 data text already done.
# Preprocessing... 6564 data text already done.
# Preprocessing... 6565 data text already done.
# Preprocessing... 6566 data text already done.
# Preprocessing... 6567 data text already done.
# Preprocessing... 6568 data text already done.
# Preprocessing... 6569 data text already done.
# Preprocessing... 6570 data text already done.
# Preprocessing... 6571 data text already done.
# Preprocessing... 6572 data text already done.
# Preprocessing... 6573 data text already done.
# Preprocessing... 6574 data text already done.
# Preprocessing... 6575 data text already done.
# Preprocessing... 6576 data text already done.
# Preprocessing... 6577 data text already done.
# Preprocessing... 6578 data text already done.
# Preprocessing... 6579 data text already done.
# Preprocessing... 6580 data text already done.
# Preprocessing... 6581 data text already done.
# Preprocessing... 6582 data text already done.
# Preprocessing... 6583 data text already done.
# Preprocessing... 6584 data text already done.
# Preprocessing... 6585 data text already done.
# Preprocessing... 6586 data text already done.
# Preprocessing... 6587 data text already done.
# Preprocessing... 6588 data text already done.
# Preprocessing... 6589 data text already done.
# Preprocessing... 6590 data text already done.
# Preprocessing... 6591 data text already done.
# Preprocessing... 6592 data text already done.
# Preprocessing... 6593 data text already done.
# Preprocessing... 6594 data text already done.
# Preprocessing... 6595 data text already done.
# Preprocessing... 6596 data text already done.
# Preprocessing... 6597 data text already done.
# Preprocessing... 6598 data text already done.
# Preprocessing... 6599 data text already done.
# Preprocessing... 6600 data text already done.
# Preprocessing... 6601 data text already done.
# Preprocessing... 6602 data text already done.
# Preprocessing... 6603 data text already done.
# Preprocessing... 6604 data text already done.
# Preprocessing... 6605 data text already done.
# Preprocessing... 6606 data text already done.
# Preprocessing... 6607 data text already done.
# Preprocessing... 6608 data text already done.
# Preprocessing... 6609 data text already done.
# Preprocessing... 6610 data text already done.
# Preprocessing... 6611 data text already done.
# Preprocessing... 6612 data text already done.
# Preprocessing... 6613 data text already done.
# Preprocessing... 6614 data text already done.
# Preprocessing... 6615 data text already done.
# Preprocessing... 6616 data text already done.
# Preprocessing... 6617 data text already done.
# Preprocessing... 6618 data text already done.
# Preprocessing... 6619 data text already done.
# Preprocessing... 6620 data text already done.
# Preprocessing... 6621 data text already done.
# Preprocessing... 6622 data text already done.
# Preprocessing... 6623 data text already done.
# Preprocessing... 6624 data text already done.
# Preprocessing... 6625 data text already done.
# Preprocessing... 6626 data text already done.
# Preprocessing... 6627 data text already done.
# Preprocessing... 6628 data text already done.
# Preprocessing... 6629 data text already done.
# Preprocessing... 6630 data text already done.
# Preprocessing... 6631 data text already done.
# Preprocessing... 6632 data text already done.
# Preprocessing... 6633 data text already done.
# Preprocessing... 6634 data text already done.
# Preprocessing... 6635 data text already done.
# Preprocessing... 6636 data text already done.
# Preprocessing... 6637 data text already done.
# Preprocessing... 6638 data text already done.
# Preprocessing... 6639 data text already done.
# Preprocessing... 6640 data text already done.
# Preprocessing... 6641 data text already done.
# Preprocessing... 6642 data text already done.
# Preprocessing... 6643 data text already done.
# Preprocessing... 6644 data text already done.
# Preprocessing... 6645 data text already done.
# Preprocessing... 6646 data text already done.
# Preprocessing... 6647 data text already done.
# Preprocessing... 6648 data text already done.
# Preprocessing... 6649 data text already done.
# Preprocessing... 6650 data text already done.
# Preprocessing... 6651 data text already done.
# Preprocessing... 6652 data text already done.
# Preprocessing... 6653 data text already done.
# Preprocessing... 6654 data text already done.
# Preprocessing... 6655 data text already done.
# Preprocessing... 6656 data text already done.
# Preprocessing... 6657 data text already done.
# Preprocessing... 6658 data text already done.
# Preprocessing... 6659 data text already done.
# Preprocessing... 6660 data text already done.
# Preprocessing... 6661 data text already done.
# Preprocessing... 6662 data text already done.
# Preprocessing... 6663 data text already done.
# Preprocessing... 6664 data text already done.
# Preprocessing... 6665 data text already done.
# Preprocessing... 6666 data text already done.
# Preprocessing... 6667 data text already done.
# Preprocessing... 6668 data text already done.
# Preprocessing... 6669 data text already done.
# Preprocessing... 6670 data text already done.
# Preprocessing... 6671 data text already done.
# Preprocessing... 6672 data text already done.
# Preprocessing... 6673 data text already done.
# Preprocessing... 6674 data text already done.
# Preprocessing... 6675 data text already done.
# Preprocessing... 6676 data text already done.
# Preprocessing... 6677 data text already done.
# Preprocessing... 6678 data text already done.
# Preprocessing... 6679 data text already done.
# Preprocessing... 6680 data text already done.
# Preprocessing... 6681 data text already done.
# Preprocessing... 6682 data text already done.
# Preprocessing... 6683 data text already done.
# Preprocessing... 6684 data text already done.
# Preprocessing... 6685 data text already done.
# Preprocessing... 6686 data text already done.
# Preprocessing... 6687 data text already done.
# Preprocessing... 6688 data text already done.
# Preprocessing... 6689 data text already done.
# Preprocessing... 6690 data text already done.
# Preprocessing... 6691 data text already done.
# Preprocessing... 6692 data text already done.
# Preprocessing... 6693 data text already done.
# Preprocessing... 6694 data text already done.
# Preprocessing... 6695 data text already done.
# Preprocessing... 6696 data text already done.
# Preprocessing... 6697 data text already done.
# Preprocessing... 6698 data text already done.
# Preprocessing... 6699 data text already done.
# Preprocessing... 6700 data text already done.
# Preprocessing... 6701 data text already done.
# Preprocessing... 6702 data text already done.
# Preprocessing... 6703 data text already done.
# Preprocessing... 6704 data text already done.
# Preprocessing... 6705 data text already done.
# Preprocessing... 6706 data text already done.
# Preprocessing... 6707 data text already done.
# Preprocessing... 6708 data text already done.
# Preprocessing... 6709 data text already done.
# Preprocessing... 6710 data text already done.
# Preprocessing... 6711 data text already done.
# Preprocessing... 6712 data text already done.
# Preprocessing... 6713 data text already done.
# Preprocessing... 6714 data text already done.
# Preprocessing... 6715 data text already done.
# Preprocessing... 6716 data text already done.
# Preprocessing... 6717 data text already done.
# Preprocessing... 6718 data text already done.
# Preprocessing... 6719 data text already done.
# Preprocessing... 6720 data text already done.
# Preprocessing... 6721 data text already done.
# Preprocessing... 6722 data text already done.
# Preprocessing... 6723 data text already done.
# Preprocessing... 6724 data text already done.
# Preprocessing... 6725 data text already done.
# Preprocessing... 6726 data text already done.
# Preprocessing... 6727 data text already done.
# Preprocessing... 6728 data text already done.
# Preprocessing... 6729 data text already done.
# Preprocessing... 6730 data text already done.
# Preprocessing... 6731 data text already done.
# Preprocessing... 6732 data text already done.
# Preprocessing... 6733 data text already done.
# Preprocessing... 6734 data text already done.
# Preprocessing... 6735 data text already done.
# Preprocessing... 6736 data text already done.
# Preprocessing... 6737 data text already done.
# Preprocessing... 6738 data text already done.
# Preprocessing... 6739 data text already done.
# Preprocessing... 6740 data text already done.
# Preprocessing... 6741 data text already done.
# Preprocessing... 6742 data text already done.
# Preprocessing... 6743 data text already done.
# Preprocessing... 6744 data text already done.
# Preprocessing... 6745 data text already done.
# Preprocessing... 6746 data text already done.
# Preprocessing... 6747 data text already done.
# Preprocessing... 6748 data text already done.
# Preprocessing... 6749 data text already done.
# Preprocessing... 6750 data text already done.
# Preprocessing... 6751 data text already done.
# Preprocessing... 6752 data text already done.
# Preprocessing... 6753 data text already done.
# Preprocessing... 6754 data text already done.
# Preprocessing... 6755 data text already done.
# Preprocessing... 6756 data text already done.
# Preprocessing... 6757 data text already done.
# Preprocessing... 6758 data text already done.
# Preprocessing... 6759 data text already done.
# Preprocessing... 6760 data text already done.
# Preprocessing... 6761 data text already done.
# Preprocessing... 6762 data text already done.
# Preprocessing... 6763 data text already done.
# Preprocessing... 6764 data text already done.
# Preprocessing... 6765 data text already done.
# Preprocessing... 6766 data text already done.
# Preprocessing... 6767 data text already done.
# Preprocessing... 6768 data text already done.
# Preprocessing... 6769 data text already done.
# Preprocessing... 6770 data text already done.
# Preprocessing... 6771 data text already done.
# Preprocessing... 6772 data text already done.
# Preprocessing... 6773 data text already done.
# Preprocessing... 6774 data text already done.
# Preprocessing... 6775 data text already done.
# Preprocessing... 6776 data text already done.
# Preprocessing... 6777 data text already done.
# Preprocessing... 6778 data text already done.
# Preprocessing... 6779 data text already done.
# Preprocessing... 6780 data text already done.
# Preprocessing... 6781 data text already done.
# Preprocessing... 6782 data text already done.
# Preprocessing... 6783 data text already done.
# Preprocessing... 6784 data text already done.
# Preprocessing... 6785 data text already done.
# Preprocessing... 6786 data text already done.
# Preprocessing... 6787 data text already done.
# Preprocessing... 6788 data text already done.
# Preprocessing... 6789 data text already done.
# Preprocessing... 6790 data text already done.
# Preprocessing... 6791 data text already done.
# Preprocessing... 6792 data text already done.
# Preprocessing... 6793 data text already done.
# Preprocessing... 6794 data text already done.
# Preprocessing... 6795 data text already done.
# Preprocessing... 6796 data text already done.
# Preprocessing... 6797 data text already done.
# Preprocessing... 6798 data text already done.
# Preprocessing... 6799 data text already done.
# Preprocessing... 6800 data text already done.
# Preprocessing... 6801 data text already done.
# Preprocessing... 6802 data text already done.
# Preprocessing... 6803 data text already done.
# Preprocessing... 6804 data text already done.
# Preprocessing... 6805 data text already done.
# Preprocessing... 6806 data text already done.
# Preprocessing... 6807 data text already done.
# Preprocessing... 6808 data text already done.
# Preprocessing... 6809 data text already done.
# Preprocessing... 6810 data text already done.
# Preprocessing... 6811 data text already done.
# Preprocessing... 6812 data text already done.
# Preprocessing... 6813 data text already done.
# Preprocessing... 6814 data text already done.
# Preprocessing... 6815 data text already done.
# Preprocessing... 6816 data text already done.
# Preprocessing... 6817 data text already done.
# Preprocessing... 6818 data text already done.
# Preprocessing... 6819 data text already done.
# Preprocessing... 6820 data text already done.
# Preprocessing... 6821 data text already done.
# Preprocessing... 6822 data text already done.
# Preprocessing... 6823 data text already done.
# Preprocessing... 6824 data text already done.
# Preprocessing... 6825 data text already done.
# Preprocessing... 6826 data text already done.
# Preprocessing... 6827 data text already done.
# Preprocessing... 6828 data text already done.
# Preprocessing... 6829 data text already done.
# Preprocessing... 6830 data text already done.
# Preprocessing... 6831 data text already done.
# Preprocessing... 6832 data text already done.
# Preprocessing... 6833 data text already done.
# Preprocessing... 6834 data text already done.
# Preprocessing... 6835 data text already done.
# Preprocessing... 6836 data text already done.
# Preprocessing... 6837 data text already done.
# Preprocessing... 6838 data text already done.
# Preprocessing... 6839 data text already done.
# Preprocessing... 6840 data text already done.
# Preprocessing... 6841 data text already done.
# Preprocessing... 6842 data text already done.
# Preprocessing... 6843 data text already done.
# Preprocessing... 6844 data text already done.
# Preprocessing... 6845 data text already done.
# Preprocessing... 6846 data text already done.
# Preprocessing... 6847 data text already done.
# Preprocessing... 6848 data text already done.
# Preprocessing... 6849 data text already done.
# Preprocessing... 6850 data text already done.
# Preprocessing... 6851 data text already done.
# Preprocessing... 6852 data text already done.
# Preprocessing... 6853 data text already done.
# Preprocessing... 6854 data text already done.
# Preprocessing... 6855 data text already done.
# Preprocessing... 6856 data text already done.
# Preprocessing... 6857 data text already done.
# Preprocessing... 6858 data text already done.
# Preprocessing... 6859 data text already done.
# Preprocessing... 6860 data text already done.
# Preprocessing... 6861 data text already done.
# Preprocessing... 6862 data text already done.
# Preprocessing... 6863 data text already done.
# Preprocessing... 6864 data text already done.
# Preprocessing... 6865 data text already done.
# Preprocessing... 6866 data text already done.
# Preprocessing... 6867 data text already done.
# Preprocessing... 6868 data text already done.
# Preprocessing... 6869 data text already done.
# Preprocessing... 6870 data text already done.
# Preprocessing... 6871 data text already done.
# Preprocessing... 6872 data text already done.
# Preprocessing... 6873 data text already done.
# Preprocessing... 6874 data text already done.
# Preprocessing... 6875 data text already done.
# Preprocessing... 6876 data text already done.
# Preprocessing... 6877 data text already done.
# Preprocessing... 6878 data text already done.
# Preprocessing... 6879 data text already done.
# Preprocessing... 6880 data text already done.
# Preprocessing... 6881 data text already done.
# Preprocessing... 6882 data text already done.
# Preprocessing... 6883 data text already done.
# Preprocessing... 6884 data text already done.
# Preprocessing... 6885 data text already done.
# Preprocessing... 6886 data text already done.
# Preprocessing... 6887 data text already done.
# Preprocessing... 6888 data text already done.
# Preprocessing... 6889 data text already done.
# Preprocessing... 6890 data text already done.
# Preprocessing... 6891 data text already done.
# Preprocessing... 6892 data text already done.
# Preprocessing... 6893 data text already done.
# Preprocessing... 6894 data text already done.
# Preprocessing... 6895 data text already done.
# Preprocessing... 6896 data text already done.
# Preprocessing... 6897 data text already done.
# Preprocessing... 6898 data text already done.
# Preprocessing... 6899 data text already done.
# Preprocessing... 6900 data text already done.
# Preprocessing... 6901 data text already done.
# Preprocessing... 6902 data text already done.
# Preprocessing... 6903 data text already done.
# Preprocessing... 6904 data text already done.
# Preprocessing... 6905 data text already done.
# Preprocessing... 6906 data text already done.
# Preprocessing... 6907 data text already done.
# Preprocessing... 6908 data text already done.
# Preprocessing... 6909 data text already done.
# Preprocessing... 6910 data text already done.
# Preprocessing... 6911 data text already done.
# Preprocessing... 6912 data text already done.
# Preprocessing... 6913 data text already done.
# Preprocessing... 6914 data text already done.
# Preprocessing... 6915 data text already done.
# Preprocessing... 6916 data text already done.
# Preprocessing... 6917 data text already done.
# Preprocessing... 6918 data text already done.
# Preprocessing... 6919 data text already done.
# Preprocessing... 6920 data text already done.
# Preprocessing... 6921 data text already done.
# Preprocessing... 6922 data text already done.
# Preprocessing... 6923 data text already done.
# Preprocessing... 6924 data text already done.
# Preprocessing... 6925 data text already done.
# Preprocessing... 6926 data text already done.
# Preprocessing... 6927 data text already done.
# Preprocessing... 6928 data text already done.
# Preprocessing... 6929 data text already done.
# Preprocessing... 6930 data text already done.
# Preprocessing... 6931 data text already done.
# Preprocessing... 6932 data text already done.
# Preprocessing... 6933 data text already done.
# Preprocessing... 6934 data text already done.
# Preprocessing... 6935 data text already done.
# Preprocessing... 6936 data text already done.
# Preprocessing... 6937 data text already done.
# Preprocessing... 6938 data text already done.
# Preprocessing... 6939 data text already done.
# Preprocessing... 6940 data text already done.
# Preprocessing... 6941 data text already done.
# Preprocessing... 6942 data text already done.
# Preprocessing... 6943 data text already done.
# Preprocessing... 6944 data text already done.
# Preprocessing... 6945 data text already done.
# Preprocessing... 6946 data text already done.
# Preprocessing... 6947 data text already done.
# Preprocessing... 6948 data text already done.
# Preprocessing... 6949 data text already done.
# Preprocessing... 6950 data text already done.
# Preprocessing... 6951 data text already done.
# Preprocessing... 6952 data text already done.
# Preprocessing... 6953 data text already done.
# Preprocessing... 6954 data text already done.
# Preprocessing... 6955 data text already done.
# Preprocessing... 6956 data text already done.
# Preprocessing... 6957 data text already done.
# Preprocessing... 6958 data text already done.
# Preprocessing... 6959 data text already done.
# Preprocessing... 6960 data text already done.
# Preprocessing... 6961 data text already done.
# Preprocessing... 6962 data text already done.
# Preprocessing... 6963 data text already done.
# Preprocessing... 6964 data text already done.
# Preprocessing... 6965 data text already done.
# Preprocessing... 6966 data text already done.
# Preprocessing... 6967 data text already done.
# Preprocessing... 6968 data text already done.
# Preprocessing... 6969 data text already done.
# Preprocessing... 6970 data text already done.
# Preprocessing... 6971 data text already done.
# Preprocessing... 6972 data text already done.
# Preprocessing... 6973 data text already done.
# Preprocessing... 6974 data text already done.
# Preprocessing... 6975 data text already done.
# Preprocessing... 6976 data text already done.
# Preprocessing... 6977 data text already done.
# Preprocessing... 6978 data text already done.
# Preprocessing... 6979 data text already done.
# Preprocessing... 6980 data text already done.
# Preprocessing... 6981 data text already done.
# Preprocessing... 6982 data text already done.
# Preprocessing... 6983 data text already done.
# ...
# Preprocessing... 10482 data text already done.
# Preprocessing... 10483 data text already done.
# Preprocessing... 10484 data text already done.
# Preprocessing... 10485 data text already done.
# Preprocessing... 10486 data text already done.
# Preprocessing... 10487 data text already done.
# Preprocessing... 10488 data text already done.
# Preprocessing... 10489 data text already done.
# Preprocessing... 10490 data text already done.
# Preprocessing... 10491 data text already done.
# Preprocessing... 10492 data text already done.
# Preprocessing... 10493 data text already done.
# Preprocessing... 10494 data text already done.
# Preprocessing... 10495 data text already done.
# Preprocessing... 10496 data text already done.
# Preprocessing... 10497 data text already done.
# Preprocessing... 10498 data text already done.
# Preprocessing... 10499 data text already done.
# Preprocessing... 10500 data text already done.
# Preprocessing... 10501 data text already done.
# Preprocessing... 10502 data text already done.
# Preprocessing... 10503 data text already done.
# Preprocessing... 10504 data text already done.
# Preprocessing... 10505 data text already done.
# Preprocessing... 10506 data text already done.
# Preprocessing... 10507 data text already done.
# Preprocessing... 10508 data text already done.
# Preprocessing... 10509 data text already done.
# Preprocessing... 10510 data text already done.
# Preprocessing... 10511 data text already done.
# Preprocessing... 10512 data text already done.
# Preprocessing... 10513 data text already done.
# Preprocessing... 10514 data text already done.
# Preprocessing... 10515 data text already done.
# Preprocessing... 10516 data text already done.
# Preprocessing... 10517 data text already done.
# Preprocessing... 10518 data text already done.
# Preprocessing... 10519 data text already done.
# Preprocessing... 10520 data text already done.
# Preprocessing... 10521 data text already done.
# Preprocessing... 10522 data text already done.
# Preprocessing... 10523 data text already done.
# Preprocessing... 10524 data text already done.
# Preprocessing... 10525 data text already done.
# Preprocessing... 10526 data text already done.
# Preprocessing... 10527 data text already done.
# Preprocessing... 10528 data text already done.
# Preprocessing... 10529 data text already done.
# Preprocessing... 10530 data text already done.
# Preprocessing... 10531 data text already done.
# Preprocessing... 10532 data text already done.
# Preprocessing... 10533 data text already done.
# Preprocessing... 10534 data text already done.
# Preprocessing... 10535 data text already done.
# Preprocessing... 10536 data text already done.
# Preprocessing... 10537 data text already done.
# Preprocessing... 10538 data text already done.
# Preprocessing... 10539 data text already done.
# Preprocessing... 10540 data text already done.
# Preprocessing... 10541 data text already done.
# Preprocessing... 10542 data text already done.
# Preprocessing... 10543 data text already done.
# Preprocessing... 10544 data text already done.
# Preprocessing... 10545 data text already done.
# Preprocessing... 10546 data text already done.
# Preprocessing... 10547 data text already done.
# Preprocessing... 10548 data text already done.
# Preprocessing... 10549 data text already done.
# Preprocessing... 10550 data text already done.
# Preprocessing... 10551 data text already done.
# Preprocessing... 10552 data text already done.
# Preprocessing... 10553 data text already done.
# Preprocessing... 10554 data text already done.
# Preprocessing... 10555 data text already done.
# Preprocessing... 10556 data text already done.
# Preprocessing... 10557 data text already done.
# Preprocessing... 10558 data text already done.
# Preprocessing... 10559 data text already done.
# Preprocessing... 10560 data text already done.
# Preprocessing... 10561 data text already done.
# Preprocessing... 10562 data text already done.
# Preprocessing... 10563 data text already done.
# Preprocessing... 10564 data text already done.
# Preprocessing... 10565 data text already done.
# Preprocessing... 10566 data text already done.
# Preprocessing... 10567 data text already done.
# Preprocessing... 10568 data text already done.
# Preprocessing... 10569 data text already done.
# Preprocessing... 10570 data text already done.
# Preprocessing... 10571 data text already done.
# Preprocessing... 10572 data text already done.
# Preprocessing... 10573 data text already done.
# Preprocessing... 10574 data text already done.
# Preprocessing... 10575 data text already done.
# Preprocessing... 10576 data text already done.
# Preprocessing... 10577 data text already done.
# Preprocessing... 10578 data text already done.
# Preprocessing... 10579 data text already done.
# Preprocessing... 10580 data text already done.
# Preprocessing... 10581 data text already done.
# Preprocessing... 10582 data text already done.
# Preprocessing... 10583 data text already done.
# Preprocessing... 10584 data text already done.
# Preprocessing... 10585 data text already done.
# Preprocessing... 10586 data text already done.
# Preprocessing... 10587 data text already done.
# Preprocessing... 10588 data text already done.
# Preprocessing... 10589 data text already done.
# Preprocessing... 10590 data text already done.
# Preprocessing... 10591 data text already done.
# Preprocessing... 10592 data text already done.
# Preprocessing... 10593 data text already done.
# Preprocessing... 10594 data text already done.
# Preprocessing... 10595 data text already done.
# Preprocessing... 10596 data text already done.
# Preprocessing... 10597 data text already done.
# Preprocessing... 10598 data text already done.
# Preprocessing... 10599 data text already done.
# Preprocessing... 10600 data text already done.
# Preprocessing... 10601 data text already done.
# Preprocessing... 10602 data text already done.
# Preprocessing... 10603 data text already done.
# Preprocessing... 10604 data text already done.
# Preprocessing... 10605 data text already done.
# Preprocessing... 10606 data text already done.
# Preprocessing... 10607 data text already done.
# Preprocessing... 10608 data text already done.
# Preprocessing... 10609 data text already done.
# Preprocessing... 10610 data text already done.
# Preprocessing... 10611 data text already done.
# Preprocessing... 10612 data text already done.
# Preprocessing... 10613 data text already done.
# Preprocessing... 10614 data text already done.
# Preprocessing... 10615 data text already done.
# Preprocessing... 10616 data text already done.
# Preprocessing... 10617 data text already done.
# Preprocessing... 10618 data text already done.
# Preprocessing... 10619 data text already done.
# Preprocessing... 10620 data text already done.
# Preprocessing... 10621 data text already done.
# Preprocessing... 10622 data text already done.
# Preprocessing... 10623 data text already done.
# Preprocessing... 10624 data text already done.
# Preprocessing... 10625 data text already done.
# Preprocessing... 10626 data text already done.
# Preprocessing... 10627 data text already done.
# Preprocessing... 10628 data text already done.
# Preprocessing... 10629 data text already done.
# Preprocessing... 10630 data text already done.
# Preprocessing... 10631 data text already done.
# Preprocessing... 10632 data text already done.
# Preprocessing... 10633 data text already done.
# Preprocessing... 10634 data text already done.
# Preprocessing... 10635 data text already done.
# Preprocessing... 10636 data text already done.
# Preprocessing... 10637 data text already done.
# Preprocessing... 10638 data text already done.
# Preprocessing... 10639 data text already done.
# Preprocessing... 10640 data text already done.
# Preprocessing... 10641 data text already done.
# Preprocessing... 10642 data text already done.
# Preprocessing... 10643 data text already done.
# Preprocessing... 10644 data text already done.
# Preprocessing... 10645 data text already done.
# Preprocessing... 10646 data text already done.
# Preprocessing... 10647 data text already done.
# Preprocessing... 10648 data text already done.
# Preprocessing... 10649 data text already done.
# Preprocessing... 10650 data text already done.
# Preprocessing... 10651 data text already done.
# Preprocessing... 10652 data text already done.
# Preprocessing... 10653 data text already done.
# Preprocessing... 10654 data text already done.
# Preprocessing... 10655 data text already done.
# Preprocessing... 10656 data text already done.
# Preprocessing... 10657 data text already done.
# Preprocessing... 10658 data text already done.
# Preprocessing... 10659 data text already done.
# Preprocessing... 10660 data text already done.
# Preprocessing... 10661 data text already done.
# Preprocessing... 10662 data text already done.
# Preprocessing... 10663 data text already done.
# Preprocessing... 10664 data text already done.
# Preprocessing... 10665 data text already done.
# Preprocessing... 10666 data text already done.
# Preprocessing... 10667 data text already done.
# Preprocessing... 10668 data text already done.
# Preprocessing... 10669 data text already done.
# Preprocessing... 10670 data text already done.
# Preprocessing... 10671 data text already done.
# Preprocessing... 10672 data text already done.
# Preprocessing... 10673 data text already done.
# Preprocessing... 10674 data text already done.
# Preprocessing... 10675 data text already done.
# Preprocessing... 10676 data text already done.
# Preprocessing... 10677 data text already done.
# Preprocessing... 10678 data text already done.
# Preprocessing... 10679 data text already done.
# Preprocessing... 10680 data text already done.
# Preprocessing... 10681 data text already done.
# Preprocessing... 10682 data text already done.
# Preprocessing... 10683 data text already done.
# Preprocessing... 10684 data text already done.
# Preprocessing... 10685 data text already done.
# Preprocessing... 10686 data text already done.
# Preprocessing... 10687 data text already done.
# Preprocessing... 10688 data text already done.
# Preprocessing... 10689 data text already done.
# Preprocessing... 10690 data text already done.
# Preprocessing... 10691 data text already done.
# Preprocessing... 10692 data text already done.
# Preprocessing... 10693 data text already done.
# Preprocessing... 10694 data text already done.
# Preprocessing... 10695 data text already done.
# Preprocessing... 10696 data text already done.
# Preprocessing... 10697 data text already done.
# Preprocessing... 10698 data text already done.
# Preprocessing... 10699 data text already done.
# Preprocessing... 10700 data text already done.
# Preprocessing... 10701 data text already done.
# Preprocessing... 10702 data text already done.
# Preprocessing... 10703 data text already done.
# Preprocessing... 10704 data text already done.
# Preprocessing... 10705 data text already done.
# Preprocessing... 10706 data text already done.
# Preprocessing... 10707 data text already done.
# Preprocessing... 10708 data text already done.
# Preprocessing... 10709 data text already done.
# Preprocessing... 10710 data text already done.
# Preprocessing... 10711 data text already done.
# Preprocessing... 10712 data text already done.
# Preprocessing... 10713 data text already done.
# Preprocessing... 10714 data text already done.
# Preprocessing... 10715 data text already done.
# Preprocessing... 10716 data text already done.
# Preprocessing... 10717 data text already done.
# Preprocessing... 10718 data text already done.
# Preprocessing... 10719 data text already done.
# Preprocessing... 10720 data text already done.
# Preprocessing... 10721 data text already done.
# Preprocessing... 10722 data text already done.
# Preprocessing... 10723 data text already done.
# Preprocessing... 10724 data text already done.
# Preprocessing... 10725 data text already done.
# Preprocessing... 10726 data text already done.
# Preprocessing... 10727 data text already done.
# Preprocessing... 10728 data text already done.
# Preprocessing... 10729 data text already done.
# Preprocessing... 10730 data text already done.
# Preprocessing... 10731 data text already done.
# Preprocessing... 10732 data text already done.
# Preprocessing... 10733 data text already done.
# Preprocessing... 10734 data text already done.
# Preprocessing... 10735 data text already done.
# Preprocessing... 10736 data text already done.
# Preprocessing... 10737 data text already done.
# Preprocessing... 10738 data text already done.
# Preprocessing... 10739 data text already done.
# Preprocessing... 10740 data text already done.
# Preprocessing... 10741 data text already done.
# Preprocessing... 10742 data text already done.
# Preprocessing... 10743 data text already done.
# Preprocessing... 10744 data text already done.
# Preprocessing... 10745 data text already done.
# Preprocessing... 10746 data text already done.
# Preprocessing... 10747 data text already done.
# Preprocessing... 10748 data text already done.
# Preprocessing... 10749 data text already done.
# Preprocessing... 10750 data text already done.
# Preprocessing... 10751 data text already done.
# Preprocessing... 10752 data text already done.
# Preprocessing... 10753 data text already done.
# Preprocessing... 10754 data text already done.
# Preprocessing... 10755 data text already done.
# Preprocessing... 10756 data text already done.
# Preprocessing... 10757 data text already done.
# Preprocessing... 10758 data text already done.
# Preprocessing... 10759 data text already done.
# Preprocessing... 10760 data text already done.
# Preprocessing... 10761 data text already done.
# Preprocessing... 10762 data text already done.
# Preprocessing... 10763 data text already done.
# Preprocessing... 10764 data text already done.
# Preprocessing... 10765 data text already done.
# Preprocessing... 10766 data text already done.
# Preprocessing... 10767 data text already done.
# Preprocessing... 10768 data text already done.
# Preprocessing... 10769 data text already done.
# Preprocessing... 10770 data text already done.
# Preprocessing... 10771 data text already done.
# Preprocessing... 10772 data text already done.
# Preprocessing... 10773 data text already done.
# Preprocessing... 10774 data text already done.
# Preprocessing... 10775 data text already done.
# Preprocessing... 10776 data text already done.
# Preprocessing... 10777 data text already done.
# Preprocessing... 10778 data text already done.
# Preprocessing... 10779 data text already done.
# Preprocessing... 10780 data text already done.
# Preprocessing... 10781 data text already done.
# Preprocessing... 10782 data text already done.
# Preprocessing... 10783 data text already done.
# Preprocessing... 10784 data text already done.
# Preprocessing... 10785 data text already done.
# Preprocessing... 10786 data text already done.
# Preprocessing... 10787 data text already done.
# Preprocessing... 10788 data text already done.
# Preprocessing... 10789 data text already done.
# Preprocessing... 10790 data text already done.
# Preprocessing... 10791 data text already done.
# Preprocessing... 10792 data text already done.
# Preprocessing... 10793 data text already done.
# Preprocessing... 10794 data text already done.
# Preprocessing... 10795 data text already done.
# Preprocessing... 10796 data text already done.
# Preprocessing... 10797 data text already done.
# Preprocessing... 10798 data text already done.
# Preprocessing... 10799 data text already done.
# Preprocessing... 10800 data text already done.
# Preprocessing... 10801 data text already done.
# Preprocessing... 10802 data text already done.
# Preprocessing... 10803 data text already done.
# Preprocessing... 10804 data text already done.
# Preprocessing... 10805 data text already done.
# Preprocessing... 10806 data text already done.
# Preprocessing... 10807 data text already done.
# Preprocessing... 10808 data text already done.
# Preprocessing... 10809 data text already done.
# Preprocessing... 10810 data text already done.
# Preprocessing... 10811 data text already done.
# Preprocessing... 10812 data text already done.
# Preprocessing... 10813 data text already done.
# Preprocessing... 10814 data text already done.
# Preprocessing... 10815 data text already done.
# Preprocessing... 10816 data text already done.
# Preprocessing... 10817 data text already done.
# Preprocessing... 10818 data text already done.
# Preprocessing... 10819 data text already done.
# Preprocessing... 10820 data text already done.
# Preprocessing... 10821 data text already done.

# %%
processed_data_inanlp = data_textual.copy()
processed_data_inanlp['Transkripsi'] = processed_data_textual
processed_data_inanlp = processed_data_inanlp.sort_values(by=['ID Ucapan'])
processed_data_inanlp = processed_data_inanlp.reset_index()
processed_data_inanlp = processed_data_inanlp.drop(columns=['index'])
processed_data_inanlp.head()
# Out:
#    ID Ucapan  ... Abstraksi Emosi
# 0  001001001  ...          Senang
# 1  001001002  ...             NaN
# 2  001001003  ...             NaN
# 3  001001004  ...             NaN
# 4  001001005  ...             NaN
#
# [5 rows x 4 columns]

# %%
processed_data_inanlp.head()
# Out:
#    ID Ucapan  ... Abstraksi Emosi
# 0  001001001  ...          Senang
# 1  001001002  ...             NaN
# 2  001001003  ...             NaN
# 3  001001004  ...             NaN
# 4  001001005  ...             NaN
#
# [5 rows x 4 columns]

# %%
processed_data_inanlp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10822 entries, 0 to 10821
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID Ucapan        10822 non-null  object
#  1   Transkripsi      10822 non-null  object
#  2   Label Emosi      10822 non-null  object
#  3   Abstraksi Emosi  2003 non-null   object
# dtypes: object(4)
# memory usage: 338.3+ KB

# %%
vocab = []
for text in processed_data_inanlp['Transkripsi']:
  for word in text.split():
    vocab.append(word)
vocab = set(vocab)
print("Total kata : ", len(vocab))
# Out:
# Total kata :  8339

# %%
joblib.dump(processed_data_inanlp, "processed_data_syntax_analyzer.pkl")
files.download("processed_data_syntax_analyzer.pkl")
