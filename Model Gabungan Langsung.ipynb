# %% [markdown]
# # Pembangunan Model Gabungan Langsung - Sistem Pengenal Emosi Cakapan

# %% [markdown]
# ## Library Preparation

# %%
# !pip install arff
# !pip install imbalanced-learn
# Out:
# Collecting arff
#   Downloading https://files.pythonhosted.org/packages/50/de/62d4446c5a6e459052c2f2d9490c370ddb6abc0766547b4cef585913598d/arff-0.9.tar.gz
# Building wheels for collected packages: arff
#   Building wheel for arff (setup.py) ... done
#   Created wheel for arff: filename=arff-0.9-cp37-none-any.whl size=4970 sha256=f41daa417196a16af8dc0628f03ee58b9cc6001c7ca259fda4b5a180a273798b
#   Stored in directory: /root/.cache/pip/wheels/04/d0/70/2c73afedd3ac25c6085b528742c69b9587cbdfa67e5194583b
# Successfully built arff
# Installing collected packages: arff
# Successfully installed arff-0.9
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.4.3)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->imbalanced-learn) (1.0.1)

# %%
import arff
import joblib
from io import StringIO
from google.colab import drive
from google.colab import files

import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow import keras
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential
from keras import layers
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.feature_extraction.text import TfidfVectorizer
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
drive.mount('/content/gdrive')
drive_dir = "/content/gdrive/MyDrive/Teknik Informatika/Semester 7/TUGAS AKHIR/TA 2"
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Audio

# %%
def read_arff_data(data):
  row = next(data)
  row = next(data)
  list_data = []
  i = 0
  while row:
    # if (i % 100 == 0):
    #   print('Reading...', i, 'data already done.')
    row_data = []
    for j in range(len(row)):
      if (j != 0 and row[j] != ''):
        row_data.append(row[j])
    list_data.append(row_data)
    try :
      row = next(data)
      i = i + 1
    except :
      break
  return np.array(list_data)

# %%
feature_akustik = read_arff_data(arff.load(drive_dir + '/Eksperimen/Data/eGeMAPS.arff'))
feature_akustik.shape
# Out:
# (10822, 88)

# %% [markdown]
# ### Textual

# %%
data = joblib.load(drive_dir + '/Eksperimen/Data/stopword.pkl')
tfidf_vectorizer = TfidfVectorizer()
feature_tfidf = tfidf_vectorizer.fit_transform(data['Transkripsi'])
feature_leksikal = np.array(feature_tfidf.todense())
feature_leksikal.shape
# Out:
# (10822, 5017)

# %% [markdown]
# ## Prepare Data Pemodelan

# %% [markdown]
# ### Scaling Data Akustik

# %%
scaler = MinMaxScaler()
feature_akustik = scaler.fit_transform(feature_akustik)
feature_akustik.shape
# Out:
# (10822, 88)

# %% [markdown]
# ### Construct Concatenate Features

# %%
def concat_features(feature_1, feature_2):
  features = []
  for i in range(len(feature_1)):
    temp = []
    temp.extend(feature_1[i])
    temp.extend(feature_2[i])
    features.append(temp)
  return np.array(features, dtype=object)

# %%
feature_concat = concat_features(feature_leksikal, feature_akustik)
feature_concat.shape
# Out:
# (10822, 5105)

# %% [markdown]
# ### Construct Sequential Data

# %%
def construct_sequential(id, data):
  sequential_datas = []
  new_data= []
  for i in range(len(id)):
    if id[i].endswith('001'):
      sequential_datas.append(new_data)
      new_data = []
    new_data.append(data[i])
  sequential_datas.append(new_data)

  return np.array(sequential_datas, dtype=object)[1:]

# %%
def construct_abstract(id, abstraksi):
  new_abstraksi = []
  for i in range(len(id)):
    if id[i].endswith('001'):
      new_abstraksi.append(abstraksi[i])

  return np.array(new_abstraksi, dtype=object)

# %%
id = data['ID Ucapan']
sequential_features_akustik, sequential_features_leksikal, sequential_features_concat = construct_sequential(id, feature_akustik), construct_sequential(id, feature_leksikal), construct_sequential(id, feature_concat)
print(sequential_features_akustik.shape, sequential_features_leksikal.shape, sequential_features_concat.shape)
# Out:
# (2003,) (2003,) (2003,)

# %%
abstraksi = construct_abstract(id, data['Abstraksi Emosi'])
print(abstraksi.shape)
# Out:
# (2003,)

# %% [markdown]
# ### Label One Hot Encoding

# %%
encoder_cakapan = OneHotEncoder(sparse=False)
abstraksi = abstraksi.reshape(-1, 1)
abstraksi = encoder_cakapan.fit_transform(abstraksi)
abstraksi.shape
# Out:
# (2003, 6)

# %% [markdown]
# ### Split Train and Test Data

# %%
X_akustik = sequential_features_akustik
X_leksikal = sequential_features_leksikal
X_concat = sequential_features_concat
y = abstraksi

# %%
X_akustik = tf.keras.preprocessing.sequence.pad_sequences(X_akustik, padding="post", dtype='float32')
X_leksikal = tf.keras.preprocessing.sequence.pad_sequences(X_leksikal, padding="post", dtype='float32')
X_concat = tf.keras.preprocessing.sequence.pad_sequences(X_concat, padding="post", dtype='float32')
y = tf.keras.preprocessing.sequence.pad_sequences(y, padding="post", dtype='float32')
print("Akustik", X_akustik.shape, y.shape)
print("Leksikal", X_leksikal.shape, y.shape)
print("Concat", X_concat.shape, y.shape)
# Out:
# Akustik (2003, 15, 88) (2003, 6)
# Leksikal (2003, 15, 5017) (2003, 6)
# Concat (2003, 15, 5105) (2003, 6)

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.15, random_state=42)
for train_index, test_index in sss.split(X_concat, y):
  train_index, test_index = train_index, test_index
print("Train data", train_index.shape)
print("Test data", test_index.shape)
# Out:
# Train data (1702,)
# Test data (301,)

# %% [markdown]
# #### Eliminate Minority Label

# %%
def get_label_idxs(list, label):
  idxs = []
  for i in range(len(list)):
    for l in label:
      if list[i] == l:
        idxs.append(i)
  return np.array(idxs)

# %%
dec_abstraksi = encoder_cakapan.inverse_transform(abstraksi)
del_idxs = get_label_idxs(dec_abstraksi, ["Jijik", "Takut"])

# %%
X_akustik_4 = np.delete(sequential_features_akustik, del_idxs)
X_leksikal_4 = np.delete(sequential_features_leksikal, del_idxs)
X_concat_4 = np.delete(sequential_features_concat, del_idxs)
label_4 = np.delete(dec_abstraksi, del_idxs)
print(X_akustik_4.shape, X_leksikal_4.shape, X_concat_4.shape, label_4.shape)
# Out:
# (1936,) (1936,) (1936,) (1936,)

# %%
encoder_cakapan_4 = OneHotEncoder(sparse=False)
label_4 = label_4.reshape(-1, 1)
label_4 = encoder_cakapan_4.fit_transform(label_4)
label_4.shape
# Out:
# (1936, 4)

# %%
X_akustik_4 = tf.keras.preprocessing.sequence.pad_sequences(X_akustik_4, padding="post", dtype='float32')
X_leksikal_4 = tf.keras.preprocessing.sequence.pad_sequences(X_leksikal_4, padding="post", dtype='float32')
X_concat_4 = tf.keras.preprocessing.sequence.pad_sequences(X_concat_4, padding="post", dtype='float32')
y_4 = tf.keras.preprocessing.sequence.pad_sequences(label_4, padding="post", dtype='float32')
print(X_akustik_4.shape, X_leksikal_4.shape, X_concat_4.shape, y_4.shape)
# Out:
# (1936, 15, 88) (1936, 15, 5017) (1936, 15, 5105) (1936, 4)

# %%
sss_4 = StratifiedShuffleSplit(n_splits=1, test_size=0.15, random_state=42)
for train_index_4, test_index_4 in sss_4.split(X_akustik_4, y_4):
  train_index_4, test_index_4 = train_index_4, test_index_4
print("Train data", train_index_4.shape)
print("Test data", test_index_4.shape)
# Out:
# Train data (1645,)
# Test data (291,)

# %% [markdown]
# ## 1. Model Gabungan Level Fitur

# %% [markdown]
# ### Modelling Preparation

# %% [markdown]
# #### Define Model

# %%
def get_gru_1(shape, label_shape):
  model = Sequential()
  model.add(layers.Masking(mask_value=0, input_shape=shape))
  model.add(layers.GRU(128))
  model.add(layers.Dense(label_shape, activation='softmax'))
  return model

def get_lstm_1(shape, label_shape):
  model = Sequential()
  model.add(layers.Masking(mask_value=0, input_shape=shape))
  model.add(layers.LSTM(128))
  model.add(layers.Dense(label_shape, activation='softmax'))
  return model

# %%
def get_gru_2(shape, label_shape):
  model = Sequential()
  model.add(layers.Masking(mask_value=0, input_shape=shape))
  model.add(layers.GRU(128))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(label_shape, activation='softmax'))
  return model

def get_lstm_2(shape, label_shape):
  model = Sequential()
  model.add(layers.Masking(mask_value=0, input_shape=shape))
  model.add(layers.LSTM(256))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(label_shape, activation='softmax'))
  return model

# %%
def get_gru_3(shape, label_shape):
  model = Sequential()
  model.add(layers.Masking(mask_value=0, input_shape=shape))
  model.add(layers.GRU(128))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.Dense(label_shape, activation='softmax'))
  return model

def get_lstm_3(shape, label_shape):
  model = Sequential()
  model.add(layers.Masking(mask_value=0, input_shape=shape))
  model.add(layers.LSTM(128))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.Dense(label_shape, activation='softmax'))
  return model

# %% [markdown]
# #### Define Training Parameter

# %%
batch_size = 32
epochs = 20
validation_split = 0.2
optimizer = 'adam'
loss = 'categorical_crossentropy'
metrics = ['accuracy']
callbacks = [EarlyStopping(monitor='val_accuracy', mode='max', min_delta=0.0001, patience=3, restore_best_weights=True)]

# %% [markdown]
# #### Define Schema Experiment

# %%
def train_5fold_cv(X, y, shape, label_shape, mode):

  loss_score = []
  accuracy_score = []  

  cv = KFold(n_splits=5, random_state=42, shuffle=True)

  for train_index, val_index in cv.split(X):
      
      X_train, X_val, y_train, y_val = X[train_index], X[val_index], y[train_index], y[val_index]
      
      model = create_model(shape, label_shape, mode)
      model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
      model.fit(X_train, y_train,
              validation_data=(X_val, y_val),
              epochs=epochs,
              batch_size=batch_size,
              callbacks=callbacks)
      
      l, a = model.evaluate(X_val, y_val)
      loss_score.append(l)
      accuracy_score.append(a)
  
  loss_score = np.round(np.mean(loss_score), 4)
  accuracy_score = np.round(np.mean(accuracy_score), 4)
  print("Loss Score : ", loss_score, "Accuracy Score : ", accuracy_score)
  return loss_score, accuracy_score

# %%
def train_stratified_random_sampling(X_train, y_train, X_test, y_test, shape, label_shape, return_sequences):

  model = None
  if return_sequences :
    model = get_contextual_model(shape, label_shape)
  else :
    model = get_classification_model(shape, label_shape)
  model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
  model.fit(X_train, y_train,
            validation_data=(X_test, y_test),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=callbacks)
      
  loss_score, accuracy_score = model.evaluate(X_test, y_test)
  loss_score = np.round(np.mean(loss_score), 4)
  accuracy_score = np.round(np.mean(accuracy_score), 4)

  print("Loss Score : ", loss_score, "Accuracy Score : ", accuracy_score)
  
  return model, accuracy_score

# %% [markdown]
# ### Model Comparation

# %%
model = ["gru 1", "gru 2", "gru 3", "lstm 1", "lstm 2", "lstm 3"]
n = 5

# %%
def run_tahap_4(X, label, model, train_index, n):
  performances = []
  for i in range(n):
    p = []
    for m in model:
      X_train, y_train = X[train_index], label[train_index]
      loss_score, accuracy_score = train_5fold_cv(X_train, y_train, X_train.shape[1:], y.shape[1], m)
      p.append((m, loss_score, accuracy_score))
    performances.append((i, p))
  return performances

# %%
performances = run_tahap_4(X_concat, y, model, train_index, n)
# Out:
# Epoch 1/10
# 43/43 [==============================] - 23s 59ms/step - loss: 1.5604 - accuracy: 0.3563 - val_loss: 1.5455 - val_accuracy: 0.3284
# Epoch 2/10
# 43/43 [==============================] - 1s 18ms/step - loss: 1.5287 - accuracy: 0.4037 - val_loss: 1.5894 - val_accuracy: 0.2815
# 11/11 [==============================] - 0s 9ms/step - loss: 1.5455 - accuracy: 0.3284
# Epoch 1/10
# 43/43 [==============================] - 7s 57ms/step - loss: 1.6310 - accuracy: 0.3348 - val_loss: 1.5031 - val_accuracy: 0.3812
# Epoch 2/10
# 43/43 [==============================] - 1s 18ms/step - loss: 1.4876 - accuracy: 0.3440 - val_loss: 1.4864 - val_accuracy: 0.3812
# Epoch 3/10
# 43/43 [==============================] - 1s 18ms/step - loss: 1.4377 - accuracy: 0.3746 - val_loss: 1.4598 - val_accuracy: 0.3812
# Epoch 4/10
# 43/43 [==============================] - 1s 18ms/step - loss: 1.4542 - accuracy: 0.3765 - val_loss: 1.4558 - val_accuracy: 0.3783
# Epoch 5/10
# 43/43 [==============================] - 1s 18ms/step - loss: 1.4030 - accuracy: 0.3746 - val_loss: 1.4521 - val_accuracy: 0.3812
# Epoch 6/10
# 43/43 [==============================] - 1s 18ms/step - loss: 1.4158 - accuracy: 0.3706 - val_loss: 1.4477 - val_accuracy: 0.3812
# Epoch 7/10
# 43/43 [==============================] - 1s 18ms/step - loss: 1.4153 - accuracy: 0.3958 - val_loss: 1.4492 - val_accuracy: 0.3783
# 11/11 [==============================] - 0s 10ms/step - loss: 1.4477 - accuracy: 0.3812
# Epoch 1/10
# 43/43 [==============================] - 6s 54ms/step - loss: 1.6500 - accuracy: 0.3454 - val_loss: 1.4574 - val_accuracy: 0.4059
# Epoch 2/10
# 43/43 [==============================] - 1s 18ms/step - loss: 1.4516 - accuracy: 0.3718 - val_loss: 1.3977 - val_accuracy: 0.4059
# Epoch 3/10
# 43/43 [==============================] - 1s 18ms/step - loss: 1.4174 - accuracy: 0.3825 - val_loss: 1.3960 - val_accuracy: 0.4059
# Epoch 4/10
# 43/43 [==============================] - 1s 19ms/step - loss: 1.4321 - accuracy: 0.3538 - val_loss: 1.3971 - val_accuracy: 0.4059
# 11/11 [==============================] - 0s 9ms/step - loss: 1.3960 - accuracy: 0.4059
# Epoch 1/10
# 43/43 [==============================] - 7s 53ms/step - loss: 1.8654 - accuracy: 0.2430 - val_loss: 1.4737 - val_accuracy: 0.3971
# Epoch 2/10
# 43/43 [==============================] - 1s 19ms/step - loss: 1.
10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4404 - accuracy: 0.3494 - val_loss: 1.3865 - val_accuracy: 0.4088
# Epoch 4/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4561 - accuracy: 0.3495 - val_loss: 1.3822 - val_accuracy: 0.4088
# Epoch 5/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4736 - accuracy: 0.3378 - val_loss: 1.3904 - val_accuracy: 0.4088
# 11/11 [==============================] - 0s 14ms/step - loss: 1.3822 - accuracy: 0.4088
# Epoch 1/10
# 43/43 [==============================] - 7s 63ms/step - loss: 1.6665 - accuracy: 0.2927 - val_loss: 1.4483 - val_accuracy: 0.3971
# Epoch 2/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4975 - accuracy: 0.3446 - val_loss: 1.4137 - val_accuracy: 0.4000
# Epoch 3/10
# 43/43 [==============================] - 1s 23ms/step - loss: 1.4576 - accuracy: 0.3719 - val_loss: 1.4078 - val_accuracy: 0.4000
# Epoch 4/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4494 - accuracy: 0.3404 - val_loss: 1.4050 - val_accuracy: 0.4000
# Epoch 5/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4366 - accuracy: 0.3764 - val_loss: 1.4066 - val_accuracy: 0.4000
# 11/11 [==============================] - 0s 13ms/step - loss: 1.4050 - accuracy: 0.4000
# Epoch 1/10
# 43/43 [==============================] - 8s 62ms/step - loss: 1.6360 - accuracy: 0.3045 - val_loss: 1.4923 - val_accuracy: 0.3500
# Epoch 2/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4646 - accuracy: 0.4005 - val_loss: 1.4379 - val_accuracy: 0.3500
# Epoch 3/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4470 - accuracy: 0.3865 - val_loss: 1.4251 - val_accuracy: 0.3529
# Epoch 4/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4373 - accuracy: 0.3854 - val_loss: 1.4192 - val_accuracy: 0.3529
# Epoch 5/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4133 - accuracy: 0.4260 - val_loss: 1.4149 - val_accuracy: 0.3529
# Epoch 6/10
# 43/43 [==============================] - 1s 24ms/step - loss: 1.4352 - accuracy: 0.3745 - val_loss: 1.4158 - val_accuracy: 0.3529
# 11/11 [==============================] - 0s 14ms/step - loss: 1.4149 - accuracy: 0.3529
# Loss Score :  1.4235 Accuracy Score :  0.3755

# %%
for p in performances:
  print("Training ke- : ", p[0])
  res = pd.DataFrame(p[1], columns=['Model', 'Loss Score', 'Accuracy Score'])
  print(res['Accuracy Score'])
# Out:
# Training ke- :  0
# 0    0.3725
# 1    0.3743
# 2    0.3743
# 3    0.3737
# 4    0.3749
# 5    0.3737
# Name: Accuracy Score, dtype: float64
# Training ke- :  1
# 0    0.3713
# 1    0.3731
# 2    0.3590
# 3    0.3737
# 4    0.3737
# 5    0.3743
# Name: Accuracy Score, dtype: float64
# Training ke- :  2
# 0    0.3702
# 1    0.3725
# 2    0.3725
# 3    0.3737
# 4    0.3737
# 5    0.3737
# Name: Accuracy Score, dtype: float64
# Training ke- :  3
# 0    0.3760
# 1    0.3737
# 2    0.3743
# 3    0.3737
# 4    0.3749
# 5    0.3755
# Name: Accuracy Score, dtype: float64
# Training ke- :  4
# 0    0.3731
# 1    0.3725
# 2    0.3749
# 3    0.3725
# 4    0.3737
# 5    0.3755
# Name: Accuracy Score, dtype: float64

# %%
res = pd.DataFrame(performances[0][1], columns=['Model', 'Loss Score', 'Accuracy Score'])
for performance in performances[1:]:
  temp = pd.DataFrame(performance[1], columns=['Model', 'Loss Score', 'Accuracy Score'])
  res['Loss Score'] += temp['Loss Score']
  res['Accuracy Score'] += temp['Accuracy Score']
res['Loss Score'] /= n
res['Accuracy Score'] /= n
print(res.sort_values(by='Accuracy Score', ascending=False, ignore_index=True))
# Out:
#     Model  Loss Score  Accuracy Score
# 0  lstm 3     1.42546         0.37454
# 1  lstm 2     1.43442         0.37418
# 2  lstm 1     1.43624         0.37346
# 3   gru 2     1.43360         0.37322
# 4   gru 1     1.43412         0.37262
# 5   gru 3     1.42700         0.37100

# %% [markdown]
# #### Training Model

# %%
def run_tahap_5(X_train, y_train, X_test, y_test, n, encoder):
  model = None
  best_acc = 0
  for i in range(n):
    model, accuracy_score = train_stratified_random_sampling(X_train, y_train, X_test, y_test, X_train.shape[1:], y.shape[1], 2, encoder)
    if best_acc < accuracy_score:
      best_acc = accuracy_score
      best_model = model
  return best_model

# %%
best_model = run_tahap_5(X_concat[train_index], y[train_index], X_concat[test_index], y[test_index], 1, encoder_cakapan)

# %%
best_model.save(drive_dir + "/Eksperimen/Model/model_gabungan_langsung_6.h5")

# %% [markdown]
# ### Evaluate Model

# %% [markdown]
# #### 6 Kelas Emosi

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.1)

# %%
def run_model(X_train, y_train, X_test, y_test, n, encoder):
  model = None
  best_acc = 0
  for i in range(n):
    model, accuracy_score = train_stratified_random_sampling(X_train, y_train, X_test, y_test, X_train.shape[1:], y_train.shape[1], "lstm 3", encoder)
    if best_acc < accuracy_score:
      best_acc = accuracy_score
      best_model = model
  return best_model

# %%
model_level_fitur = run_model(X_concat[train_index], y[train_index], X_concat[test_index], y[test_index], 1, encoder_cakapan)
# Out:
# Epoch 1/20
# 54/54 [==============================] - 7s 37ms/step - loss: 1.5563 - accuracy: 0.3230 - val_loss: 1.4133 - val_accuracy: 0.3754
# Epoch 2/20
# 54/54 [==============================] - 1s 13ms/step - loss: 1.4081 - accuracy: 0.3652 - val_loss: 1.4112 - val_accuracy: 0.3754
# Epoch 3/20
# 54/54 [==============================] - 1s 14ms/step - loss: 1.3579 - accuracy: 0.3936 - val_loss: 1.3696 - val_accuracy: 0.3754
# Epoch 4/20
# 54/54 [==============================] - 1s 14ms/step - loss: 1.3141 - accuracy: 0.4143 - val_loss: 1.4057 - val_accuracy: 0.4086
# Epoch 5/20
# 54/54 [==============================] - 1s 14ms/step - loss: 1.1452 - accuracy: 0.5215 - val_loss: 1.3551 - val_accuracy: 0.4485
# Epoch 6/20
# 54/54 [==============================] - 1s 14ms/step - loss: 0.7878 - accuracy: 0.7281 - val_loss: 1.6432 - val_accuracy: 0.4817
# Epoch 7/20
# 54/54 [==============================] - 1s 14ms/step - loss: 0.5767 - accuracy: 0.7976 - val_loss: 1.4634 - val_accuracy: 0.5216
# Epoch 8/20
# 54/54 [==============================] - 1s 14ms/step - loss: 0.3317 - accuracy: 0.8941 - val_loss: 1.9329 - val_accuracy: 0.5083
# Epoch 9/20
# 54/54 [==============================] - 1s 14ms/step - loss: 0.2439 - accuracy: 0.9277 - val_loss: 1.8160 - val_accuracy: 0.4983
# Epoch 10/20
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0995 - accuracy: 0.9776 - val_loss: 2.1332 - val_accuracy: 0.5083
# 10/10 [==============================] - 0s 7ms/step - loss: 1.4634 - accuracy: 0.5216
# Loss Score :  1.4634 Accuracy Score :  0.5216
#               precision    recall  f1-score   support
#
#        Jijik     0.0000    0.0000    0.0000         1
#        Marah     0.8000    0.1905    0.3077        42
#        Sedih     0.4435    0.6395    0.5238        86
#       Senang     0.6705    0.5221    0.5871       113
#        Takut     0.0000    0.0000    0.0000         9
#     Terkejut     0.4430    0.7000    0.5426        50
#
#     accuracy                         0.5216       301
#    macro avg     0.3928    0.3420    0.3269       301
# weighted avg     0.5636    0.5216    0.5031       301
#
# [[ 0  0  0  0  0  1]
#  [ 0  8 19  5  0 10]
#  [ 0  1 55 19  0 11]
#  [ 0  0 37 59  0 17]
#  [ 0  0  3  1  0  5]
#  [ 0  1 10  4  0 35]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
pred = model_level_fitur.predict(X_concat[test_index])
y_pred = encoder_cakapan.inverse_transform(pred)
y_true = encoder_cakapan.inverse_transform(y[test_index])
print(classification_report(y_true, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        Jijik     0.0000    0.0000    0.0000         1
#        Marah     0.6129    0.4524    0.5205        42
#        Sedih     0.4795    0.4070    0.4403        86
#       Senang     0.5745    0.7168    0.6378       113
#        Takut     0.0000    0.0000    0.0000         9
#     Terkejut     0.5179    0.5800    0.5472        50
#
#     accuracy                         0.5449       301
#    macro avg     0.3641    0.3594    0.3576       301
# weighted avg     0.5242    0.5449    0.5288       301
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model_level_fitur.save(drive_dir + "/Eksperimen/Model/model_gabungan_langsung_6.h5")

# %%
model_level_fitur = keras.models.load_model(drive_dir + "/Eksperimen/Model/model_gabungan_langsung_6.h5")
pred_gabungan_fitur = model_level_fitur.predict(X_concat[test_index])
y_pred = encoder_cakapan.inverse_transform(pred_gabungan_fitur)
y_true = encoder_cakapan.inverse_transform(y[test_index])
print(classification_report(y_true, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        Jijik     0.0000    0.0000    0.0000         1
#        Marah     0.6129    0.4524    0.5205        42
#        Sedih     0.4795    0.4070    0.4403        86
#       Senang     0.5745    0.7168    0.6378       113
#        Takut     0.0000    0.0000    0.0000         9
#     Terkejut     0.5179    0.5800    0.5472        50
#
#     accuracy                         0.5449       301
#    macro avg     0.3641    0.3594    0.3576       301
# weighted avg     0.5242    0.5449    0.5288       301
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### 4 Kelas Emosi

# %%
model_level_fitur_4 = run_model(X_concat_4[train_index_4], y_4[train_index_4], X_concat_4[test_index_4], y_4[test_index_4], 10, encoder_cakapan_4)
# Out:
# Epoch 1/20
# 52/52 [==============================] - 7s 37ms/step - loss: 1.3199 - accuracy: 0.3953 - val_loss: 1.2883 - val_accuracy: 0.3780
# Epoch 2/20
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2852 - accuracy: 0.4159 - val_loss: 1.2509 - val_accuracy: 0.4089
# Epoch 3/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.1863 - accuracy: 0.4613 - val_loss: 1.2860 - val_accuracy: 0.4605
# Epoch 4/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.9177 - accuracy: 0.6523 - val_loss: 1.1112 - val_accuracy: 0.5395
# Epoch 5/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.5799 - accuracy: 0.8111 - val_loss: 1.3979 - val_accuracy: 0.4948
# Epoch 6/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.5236 - accuracy: 0.8185 - val_loss: 1.3716 - val_accuracy: 0.4742
# Epoch 7/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2441 - accuracy: 0.9274 - val_loss: 1.2827 - val_accuracy: 0.5086
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1112 - accuracy: 0.5395
# Loss Score :  1.1112 Accuracy Score :  0.5395
#               precision    recall  f1-score   support
#
#        Marah     0.6154    0.1905    0.2909        42
#        Sedih     0.5000    0.4186    0.4557        86
#       Senang     0.5414    0.7522    0.6296       113
#     Terkejut     0.5714    0.5600    0.5657        50
#
#     accuracy                         0.5395       291
#    macro avg     0.5571    0.4803    0.4855       291
# weighted avg     0.5450    0.5395    0.5183       291
#
# [[ 8 12 14  8]
#  [ 3 36 42  5]
#  [ 2 18 85  8]
#  [ 0  6 16 28]]
# Epoch 1/20
# 52/52 [==============================] - 6s 36ms/step - loss: 1.3352 - accuracy: 0.3710 - val_loss: 1.3002 - val_accuracy: 0.3883
# Epoch 2/20
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2862 - accuracy: 0.3812 - val_loss: 1.2738 - val_accuracy: 0.3746
# Epoch 3/20
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1622 - accuracy: 0.4778 - val_loss: 1.1373 - val_accuracy: 0.5223
# Epoch 4/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.9307 - accuracy: 0.6365 - val_loss: 1.0903 - val_accuracy: 0.5498
# Epoch 5/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.7001 - accuracy: 0.7428 - val_loss: 1.2964 - val_accuracy: 0.5052
# Epoch 6/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.4450 - accuracy: 0.8493 - val_loss: 1.1214 - val_accuracy: 0.5498
# Epoch 7/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2911 - accuracy: 0.9052 - val_loss: 1.9253 - val_accuracy: 0.4605
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0903 - accuracy: 0.5498
# Loss Score :  1.0903 Accuracy Score :  0.5498
#               precision    recall  f1-score   support
#
#        Marah     0.4667    0.5000    0.4828        42
#        Sedih     0.5667    0.1977    0.2931        86
#       Senang     0.5613    0.7699    0.6493       113
#     Terkejut     0.5738    0.7000    0.6306        50
#
#     accuracy                         0.5498       291
#    macro avg     0.5421    0.5419    0.5139       291
# weighted avg     0.5514    0.5498    0.5168       291
#
# [[21  2 11  8]
#  [13 17 48  8]
#  [ 7  9 87 10]
#  [ 4  2  9 35]]
# Epoch 1/20
# 52/52 [==============================] - 5s 37ms/step - loss: 1.3301 - accuracy: 0.3407 - val_loss: 1.2896 - val_accuracy: 0.3883
# Epoch 2/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2853 - accuracy: 0.3850 - val_loss: 1.2725 - val_accuracy: 0.3677
# Epoch 3/20
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2183 - accuracy: 0.4533 - val_loss: 1.1754 - val_accuracy: 0.5258
# Epoch 4/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.9959 - accuracy: 0.5926 - val_loss: 1.0675 - val_accuracy: 0.5430
# Epoch 5/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.6101 - accuracy: 0.7940 - val_loss: 1.1333 - val_accuracy: 0.5430
# Epoch 6/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.4004 - accuracy: 0.8711 - val_loss: 1.4728 - val_accuracy: 0.5120
# Epoch 7/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2258 - accuracy: 0.9230 - val_loss: 1.2528 - val_accuracy: 0.5739
# Epoch 8/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.1660 - accuracy: 0.9634 - val_loss: 1.7772 - val_accuracy: 0.5189
# Epoch 9/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.1352 - accuracy: 0.9563 - val_loss: 1.9345 - val_accuracy: 0.5464
# Epoch 10/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0300 - accuracy: 0.9953 - val_loss: 2.2057 - val_accuracy: 0.5533
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2528 - accuracy: 0.5739
# Loss Score :  1.2528 Accuracy Score :  0.5739
#               precision    recall  f1-score   support
#
#        Marah     0.6061    0.4762    0.5333        42
#        Sedih     0.5062    0.4767    0.4910        86
#       Senang     0.6325    0.6549    0.6435       113
#     Terkejut     0.5333    0.6400    0.5818        50
#
#     accuracy                         0.5739       291
#    macro avg     0.5695    0.5620    0.5624       291
# weighted avg     0.5743    0.5739    0.5719       291
#
# [[20 12  4  6]
#  [ 5 41 29 11]
#  [ 5 23 74 11]
#  [ 3  5 10 32]]
# Epoch 1/20
# 52/52 [==============================] - 5s 36ms/step - loss: 1.3209 - accuracy: 0.3651 - val_loss: 1.3183 - val_accuracy: 0.3883
# Epoch 2/20
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2849 - accuracy: 0.4023 - val_loss: 1.2701 - val_accuracy: 0.4124
# Epoch 3/20
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1652 - accuracy: 0.4750 - val_loss: 1.2428 - val_accuracy: 0.4296
# Epoch 4/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.9308 - accuracy: 0.6391 - val_loss: 1.3594 - val_accuracy: 0.4880
# Epoch 5/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.7599 - accuracy: 0.7134 - val_loss: 1.2937 - val_accuracy: 0.4914
# Epoch 6/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.4065 - accuracy: 0.8761 - val_loss: 1.4524 - val_accuracy: 0.4502
# Epoch 7/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2609 - accuracy: 0.9356 - val_loss: 1.4863 - val_accuracy: 0.5326
# Epoch 8/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.1018 - accuracy: 0.9811 - val_loss: 1.7406 - val_accuracy: 0.4983
# Epoch 9/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0897 - accuracy: 0.9811 - val_loss: 1.9154 - val_accuracy: 0.5120
# Epoch 10/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0826 - accuracy: 0.9786 - val_loss: 2.6444 - val_accuracy: 0.4330
# 10/10 [==============================] - 0s 8ms/step - loss: 1.4863 - accuracy: 0.5326
# Loss Score :  1.4863 Accuracy Score :  0.5326
#               precision    recall  f1-score   support
#
#        Marah     0.5106    0.5714    0.5393        42
#        Sedih     0.4444    0.4186    0.4311        86
#       Senang     0.6289    0.5398    0.5810       113
#     Terkejut     0.5152    0.6800    0.5862        50
#
#     accuracy                         0.5326       291
#    macro avg     0.5248    0.5525    0.5344       291
# weighted avg     0.5378    0.5326    0.5316       291
#
# [[24  9  3  6]
#  [13 36 29  8]
#  [ 6 28 61 18]
#  [ 4  8  4 34]]
# Epoch 1/20
# 52/52 [==============================] - 6s 37ms/step - loss: 1.3177 - accuracy: 0.3710 - val_loss: 1.2924 - val_accuracy: 0.3986
# Epoch 2/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2829 - accuracy: 0.3898 - val_loss: 1.2325 - val_accuracy: 0.3986
# Epoch 3/20
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1655 - accuracy: 0.4789 - val_loss: 1.1669 - val_accuracy: 0.4467
# Epoch 4/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.9452 - accuracy: 0.5938 - val_loss: 1.1872 - val_accuracy: 0.4605
# Epoch 5/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.6738 - accuracy: 0.7647 - val_loss: 1.2497 - val_accuracy: 0.5430
# Epoch 6/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.4500 - accuracy: 0.8564 - val_loss: 1.3583 - val_accuracy: 0.5258
# Epoch 7/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2069 - accuracy: 0.9398 - val_loss: 1.3977 - val_accuracy: 0.5258
# Epoch 8/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.1645 - accuracy: 0.9584 - val_loss: 1.9422 - val_accuracy: 0.5120
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2497 - accuracy: 0.5430
# Loss Score :  1.2497 Accuracy Score :  0.543
#               precision    recall  f1-score   support
#
#        Marah     0.8182    0.2143    0.3396        42
#        Sedih     0.5263    0.3488    0.4196        86
#       Senang     0.5217    0.8496    0.6465       113
#     Terkejut     0.5897    0.4600    0.5169        50
#
#     accuracy                         0.5430       291
#    macro avg     0.6140    0.4682    0.4806       291
# weighted avg     0.5776    0.5430    0.5129       291
#
# [[ 9 10 15  8]
#  [ 0 30 52  4]
#  [ 2 11 96  4]
#  [ 0  6 21 23]]
# Epoch 1/20
# 52/52 [==============================] - 5s 37ms/step - loss: 1.3249 - accuracy: 0.3716 - val_loss: 1.3101 - val_accuracy: 0.3505
# Epoch 2/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2833 - accuracy: 0.4180 - val_loss: 1.2436 - val_accuracy: 0.3952
# Epoch 3/20
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1885 - accuracy: 0.4580 - val_loss: 1.2069 - val_accuracy: 0.4227
# Epoch 4/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.9513 - accuracy: 0.6143 - val_loss: 1.2518 - val_accuracy: 0.4605
# Epoch 5/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.6584 - accuracy: 0.7528 - val_loss: 1.1796 - val_accuracy: 0.4880
# Epoch 6/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.4702 - accuracy: 0.8390 - val_loss: 1.4527 - val_accuracy: 0.5258
# Epoch 7/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2632 - accuracy: 0.9205 - val_loss: 1.6016 - val_accuracy: 0.4948
# Epoch 8/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.1473 - accuracy: 0.9582 - val_loss: 1.8264 - val_accuracy: 0.4742
# Epoch 9/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0966 - accuracy: 0.9776 - val_loss: 1.7360 - val_accuracy: 0.5189
# 10/10 [==============================] - 0s 7ms/step - loss: 1.4527 - accuracy: 0.5258
# Loss Score :  1.4527 Accuracy Score :  0.5258
#               precision    recall  f1-score   support
#
#        Marah     0.5769    0.3571    0.4412        42
#        Sedih     0.5116    0.2558    0.3411        86
#       Senang     0.5548    0.7168    0.6255       113
#     Terkejut     0.4605    0.7000    0.5556        50
#
#     accuracy                         0.5258       291
#    macro avg     0.5260    0.5074    0.4908       291
# weighted avg     0.5290    0.5258    0.5028       291
#
# [[15  5  9 13]
#  [ 7 22 45 12]
#  [ 3 13 81 16]
#  [ 1  3 11 35]]
# Epoch 1/20
# 52/52 [==============================] - 5s 37ms/step - loss: 1.3339 - accuracy: 0.3571 - val_loss: 1.2942 - val_accuracy: 0.3643
# Epoch 2/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2978 - accuracy: 0.4139 - val_loss: 1.2662 - val_accuracy: 0.4021
# Epoch 3/20
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1832 - accuracy: 0.4804 - val_loss: 1.1542 - val_accuracy: 0.5223
# Epoch 4/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.9140 - accuracy: 0.6458 - val_loss: 1.2346 - val_accuracy: 0.4742
# Epoch 5/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.6385 - accuracy: 0.7789 - val_loss: 1.1874 - val_accuracy: 0.5567
# Epoch 6/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.4105 - accuracy: 0.8746 - val_loss: 1.2810 - val_accuracy: 0.4364
# Epoch 7/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3767 - accuracy: 0.8957 - val_loss: 1.3427 - val_accuracy: 0.5189
# Epoch 8/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.2127 - accuracy: 0.9489 - val_loss: 2.1345 - val_accuracy: 0.4330
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1874 - accuracy: 0.5567
# Loss Score :  1.1874 Accuracy Score :  0.5567
#               precision    recall  f1-score   support
#
#        Marah     0.6957    0.3810    0.4923        42
#        Sedih     0.5068    0.4302    0.4654        86
#       Senang     0.5968    0.6549    0.6245       113
#     Terkejut     0.4930    0.7000    0.5785        50
#
#     accuracy                         0.5567       291
#    macro avg     0.5731    0.5415    0.5402       291
# weighted avg     0.5666    0.5567    0.5505       291
#
# [[16  9  8  9]
#  [ 2 37 34 13]
#  [ 4 21 74 14]
#  [ 1  6  8 35]]
# Epoch 1/20
# 52/52 [==============================] - 6s 38ms/step - loss: 1.3225 - accuracy: 0.3801 - val_loss: 1.2854 - val_accuracy: 0.3883
# Epoch 2/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2718 - accuracy: 0.4126 - val_loss: 1.2603 - val_accuracy: 0.3814
# Epoch 3/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.1906 - accuracy: 0.4558 - val_loss: 1.5950 - val_accuracy: 0.3986
# Epoch 4/20
# 52/52 [==============================] - 1s 15ms/step - loss: 0.9933 - accuracy: 0.6038 - val_loss: 1.1673 - val_accuracy: 0.4983
# Epoch 5/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.7279 - accuracy: 0.7654 - val_loss: 1.5053 - val_accuracy: 0.5086
# Epoch 6/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.4792 - accuracy: 0.8386 - val_loss: 1.4130 - val_accuracy: 0.4708
# Epoch 7/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2383 - accuracy: 0.9314 - val_loss: 1.7569 - val_accuracy: 0.4742
# Epoch 8/20
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2038 - accuracy: 0.9333 - val_loss: 2.4769 - val_accuracy: 0.4639
# 10/10 [==============================] - 0s 7ms/step - loss: 1.5053 - accuracy: 0.5086
# Loss Score :  1.5053 Accuracy Score :  0.5086
#               precision    recall  f1-score   support
#
#        Marah     0.8750    0.1667    0.2800        42
#        Sedih     0.4839    0.1744    0.2564        86
#       Senang     0.4857    0.9027    0.6316       113
#     Terkejut     0.5714    0.4800    0.5217        50
#
#     accuracy                         0.5086       291
#    macro avg     0.6040    0.4309    0.4224       291
# weighted avg     0.5561    0.5086    0.4511       291
#
# [[  7   8  20   7]
#  [  1  15  65   5]
#  [  0   5 102   6]
#  [  0   3  23  24]]
# Epoch 1/20
# 52/52 [==============================] - 5s 38ms/step - loss: 1.3258 - accuracy: 0.3523 - val_loss: 1.3046 - val_accuracy: 0.3746
# Epoch 2/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2873 - accuracy: 0.4024 - val_loss: 1.3073 - val_accuracy: 0.4227
# Epoch 3/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2526 - accuracy: 0.4340 - val_loss: 1.2215 - val_accuracy: 0.4089
# Epoch 4/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.0494 - accuracy: 0.5161 - val_loss: 1.2035 - val_accuracy: 0.4364
# Epoch 5/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.8100 - accuracy: 0.7178 - val_loss: 1.2605 - val_accuracy: 0.5052
# Epoch 6/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.5170 - accuracy: 0.8342 - val_loss: 1.2500 - val_accuracy: 0.5155
# Epoch 7/20
# 52/52 [==============================] - 1s 15ms/step - loss: 0.2728 - accuracy: 0.9178 - val_loss: 1.5124 - val_accuracy: 0.5326
# Epoch 8/20
# 52/52 [==============================] - 1s 16ms/step - loss: 0.1489 - accuracy: 0.9586 - val_loss: 1.6748 - val_accuracy: 0.5326
# Epoch 9/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.1224 - accuracy: 0.9649 - val_loss: 2.0150 - val_accuracy: 0.5017
# Epoch 10/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0531 - accuracy: 0.9881 - val_loss: 1.8685 - val_accuracy: 0.5189
# 10/10 [==============================] - 0s 8ms/step - loss: 1.5124 - accuracy: 0.5326
# Loss Score :  1.5124 Accuracy Score :  0.5326
#               precision    recall  f1-score   support
#
#        Marah     0.4844    0.7381    0.5849        42
#        Sedih     0.4353    0.4302    0.4327        86
#       Senang     0.5842    0.5221    0.5514       113
#     Terkejut     0.6829    0.5600    0.6154        50
#
#     accuracy                         0.5326       291
#    macro avg     0.5467    0.5626    0.5461       291
# weighted avg     0.5427    0.5326    0.5322       291
#
# [[31  6  4  1]
#  [16 37 28  5]
#  [11 36 59  7]
#  [ 6  6 10 28]]
# Epoch 1/20
# 52/52 [==============================] - 6s 39ms/step - loss: 1.3408 - accuracy: 0.3357 - val_loss: 1.2939 - val_accuracy: 0.3883
# Epoch 2/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2826 - accuracy: 0.3828 - val_loss: 1.2588 - val_accuracy: 0.3643
# Epoch 3/20
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2156 - accuracy: 0.4245 - val_loss: 1.2751 - val_accuracy: 0.4330
# Epoch 4/20
# 52/52 [==============================] - 1s 15ms/step - loss: 1.0014 - accuracy: 0.6056 - val_loss: 1.1468 - val_accuracy: 0.4742
# Epoch 5/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.6777 - accuracy: 0.7702 - val_loss: 1.1293 - val_accuracy: 0.5326
# Epoch 6/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.5014 - accuracy: 0.8480 - val_loss: 1.5246 - val_accuracy: 0.5017
# Epoch 7/20
# 52/52 [==============================] - 1s 14ms/step - loss: 0.2916 - accuracy: 0.9143 - val_loss: 1.7187 - val_accuracy: 0.4811
# Epoch 8/20
# 52/52 [==============================] - 1s 15ms/step - loss: 0.2176 - accuracy: 0.9336 - val_loss: 1.7958 - val_accuracy: 0.5086
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1293 - accuracy: 0.5326
# Loss Score :  1.1293 Accuracy Score :  0.5326
#               precision    recall  f1-score   support
#
#        Marah     0.6875    0.2619    0.3793        42
#        Sedih     0.4114    0.7558    0.5328        86
#       Senang     0.7342    0.5133    0.6042       113
#     Terkejut     0.5526    0.4200    0.4773        50
#
#     accuracy                         0.5326       291
#    macro avg     0.5964    0.4877    0.4984       291
# weighted avg     0.6009    0.5326    0.5288       291
#
# [[11 24  1  6]
#  [ 1 65 13  7]
#  [ 2 49 58  4]
#  [ 2 20  7 21]]

# %%
pred = model_level_fitur_4.predict(X_concat_4[test_index_4])
y_pred = encoder_cakapan_4.inverse_transform(pred)
y_true = encoder_cakapan_4.inverse_transform(y_4[test_index_4])
print(classification_report(y_true, y_pred, digits=4))
print(confusion_matrix(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Marah     0.6061    0.4762    0.5333        42
#        Sedih     0.5062    0.4767    0.4910        86
#       Senang     0.6325    0.6549    0.6435       113
#     Terkejut     0.5333    0.6400    0.5818        50
#
#     accuracy                         0.5739       291
#    macro avg     0.5695    0.5620    0.5624       291
# weighted avg     0.5743    0.5739    0.5719       291
#
# [[20 12  4  6]
#  [ 5 41 29 11]
#  [ 5 23 74 11]
#  [ 3  5 10 32]]

# %%
model_level_fitur_4.save(drive_dir + "/Eksperimen/Model/model_gabungan_langsung_4.h5")

# %% [markdown]
# ## 2. Model Gabungan Level Keputusan

# %% [markdown]
# ### 6 Kelas

# %% [markdown]
# #### Load Model

# %%
model_akustik = keras.models.load_model(drive_dir + "/Eksperimen/Model/model_akustik_langsung_6.h5")
model_leksikal = keras.models.load_model(drive_dir + "/Eksperimen/Model/model_leksikal_langsung_6.h5")

# %% [markdown]
# #### Evaluation Model

# %%
pred_akustik = model_akustik.predict(X_akustik[test_index])
pred_leksikal = model_leksikal.predict(X_leksikal[test_index])

# %%
y_pred = encoder_cakapan.inverse_transform(pred_akustik)
y_true = encoder_cakapan.inverse_transform(y[test_index])
print(classification_report(y_true, y_pred, digits=4))
print(confusion_matrix(y_true, y_pred))

y_pred = encoder_cakapan.inverse_transform(pred_leksikal)
y_true = encoder_cakapan.inverse_transform(y[test_index])
print(classification_report(y_true, y_pred, digits=4))
print(confusion_matrix(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Jijik     0.0000    0.0000    0.0000         1
#        Marah     0.5217    0.2857    0.3692        42
#        Sedih     0.5250    0.2442    0.3333        86
#       Senang     0.4009    0.7522    0.5231       113
#        Takut     0.0000    0.0000    0.0000         9
#     Terkejut     0.5000    0.2600    0.3421        50
#
#     accuracy                         0.4352       301
#    macro avg     0.3246    0.2570    0.2613       301
# weighted avg     0.4564    0.4352    0.4000       301
#
# [[ 0  0  0  0  0  1]
#  [ 0 12  3 26  0  1]
#  [ 0  3 21 61  0  1]
#  [ 0  6 12 85  0 10]
#  [ 0  0  0  9  0  0]
#  [ 0  2  4 31  0 13]]
#               precision    recall  f1-score   support
#
#        Jijik     0.0000    0.0000    0.0000         1
#        Marah     0.7083    0.4048    0.5152        42
#        Sedih     0.4227    0.4767    0.4481        86
#       Senang     0.5796    0.8053    0.6741       113
#        Takut     0.0000    0.0000    0.0000         9
#     Terkejut     0.6087    0.2800    0.3836        50
#
#     accuracy                         0.5415       301
#    macro avg     0.3866    0.3278    0.3368       301
# weighted avg     0.5383    0.5415    0.5167       301
#
# [[ 0  0  1  0  0  0]
#  [ 0 17 14 10  0  1]
#  [ 0  2 41 39  0  4]
#  [ 0  0 19 91  0  3]
#  [ 0  1  6  1  0  1]
#  [ 0  4 16 16  0 14]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
pred_gabungan_keputusan = []
for i in range(len(pred_akustik)):
  if (pred_akustik[i].max() > pred_leksikal[i].max()):
    print("Akustik", pred_akustik[i].max(), pred_leksikal[i].max())
    pred_gabungan_keputusan.append(pred_akustik[i])
  else :
    print("Leksikal", pred_akustik[i].max(), pred_leksikal[i].max())
    pred_gabungan_keputusan.append(pred_leksikal[i])
pred_gabungan_keputusan = np.array(pred_gabungan_keputusan)

# %%
y_pred = encoder_cakapan.inverse_transform(pred_gabungan_keputusan)
y_true = encoder_cakapan.inverse_transform(y[test_index])
print(classification_report(y_true, y_pred, digits=4))
print(confusion_matrix(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Jijik     0.0000    0.0000    0.0000         1
#        Marah     0.6000    0.2143    0.3158        42
#        Sedih     0.4821    0.3140    0.3803        86
#       Senang     0.4593    0.8496    0.5963       113
#        Takut     0.0000    0.0000    0.0000         9
#     Terkejut     0.6190    0.2600    0.3662        50
#
#     accuracy                         0.4817       301
#    macro avg     0.3601    0.2730    0.2764       301
# weighted avg     0.4967    0.4817    0.4374       301
#
# [[ 0  0  0  0  0  1]
#  [ 0  9 11 21  0  1]
#  [ 0  2 27 56  0  1]
#  [ 0  2 10 96  0  5]
#  [ 0  0  0  9  0  0]
#  [ 0  2  8 27  0 13]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 4 Kelas

# %% [markdown]
# #### Load Model

# %%
model_akustik_4 = keras.models.load_model(drive_dir + "/Eksperimen/Model/model_akustik_langsung_4.h5")
model_leksikal_4 = keras.models.load_model(drive_dir + "/Eksperimen/Model/model_leksikal_langsung_4.h5")

# %% [markdown]
# #### Evaluation Model

# %%
pred_akustik_4 = model_akustik_4.predict(X_akustik_4[test_index_4])
pred_leksikal_4 = model_leksikal_4.predict(X_leksikal_4[test_index_4])

# %%
y_pred = encoder_cakapan_4.inverse_transform(pred_akustik_4)
y_true = encoder_cakapan_4.inverse_transform(y_4[test_index_4])
print(classification_report(y_true, y_pred, digits=4))
print(confusion_matrix(y_true, y_pred))

y_pred = encoder_cakapan_4.inverse_transform(pred_leksikal_4)
y_true = encoder_cakapan_4.inverse_transform(y_4[test_index_4])
print(classification_report(y_true, y_pred, digits=4))
print(confusion_matrix(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Marah     0.4483    0.3095    0.3662        42
#        Sedih     0.4464    0.2907    0.3521        86
#       Senang     0.4286    0.7168    0.5364       113
#     Terkejut     0.4706    0.1600    0.2388        50
#
#     accuracy                         0.4364       291
#    macro avg     0.4485    0.3693    0.3734       291
# weighted avg     0.4439    0.4364    0.4062       291
#
# [[13  5 21  3]
#  [ 4 25 56  1]
#  [ 8 19 81  5]
#  [ 4  7 31  8]]
#               precision    recall  f1-score   support
#
#        Marah     0.5526    0.5000    0.5250        42
#        Sedih     0.4375    0.4070    0.4217        86
#       Senang     0.6202    0.7080    0.6612       113
#     Terkejut     0.5455    0.4800    0.5106        50
#
#     accuracy                         0.5498       291
#    macro avg     0.5389    0.5237    0.5296       291
# weighted avg     0.5436    0.5498    0.5449       291
#
# [[21 13  5  3]
#  [ 8 35 34  9]
#  [ 3 22 80  8]
#  [ 6 10 10 24]]

# %%
pred_gabungan_4 = []
for i in range(len(pred_akustik_4)):
  if (pred_akustik_4[i].max() > pred_leksikal_4[i].max()):
    print("Akustik", pred_akustik_4[i].max(), pred_leksikal_4[i].max())
    pred_gabungan_4.append(pred_akustik_4[i])
  else :
    print("Leksikal", pred_akustik_4[i].max(), pred_leksikal_4[i].max())
    pred_gabungan_4.append(pred_leksikal_4[i])
pred_gabungan_4 = np.array(pred_gabungan_4)

# %%
y_pred = encoder_cakapan_4.inverse_transform(pred_gabungan_4)
y_true = encoder_cakapan_4.inverse_transform(y_4[test_index_4])
print(classification_report(y_true, y_pred, digits=4))
print(confusion_matrix(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Marah     0.5429    0.4524    0.4935        42
#        Sedih     0.4348    0.3488    0.3871        86
#       Senang     0.5541    0.7699    0.6444       113
#     Terkejut     0.7333    0.4400    0.5500        50
#
#     accuracy                         0.5430       291
#    macro avg     0.5663    0.5028    0.5188       291
# weighted avg     0.5480    0.5430    0.5304       291
#
# [[19 11 10  2]
#  [ 9 30 45  2]
#  [ 3 19 87  4]
#  [ 4  9 15 22]]

# %% [markdown]
# ## Hasil Akhir Pengenalan Emosi

# %% [markdown]
# ### 6 kelas emosi

# %%
pred_akustik_proba = pred_akustik.max(axis=1)
pred_leksikal_proba = pred_leksikal.max(axis=1)
pred_gabungan_fitur_proba = pred_gabungan_fitur.max(axis=1)
pred_gabungan_keputusan_proba = pred_gabungan_keputusan.max(axis=1)

# %%
pred_akustik = encoder_cakapan.inverse_transform(pred_akustik).reshape(301,)
pred_leksikal = encoder_cakapan.inverse_transform(pred_leksikal).reshape(301,)
pred_gabungan_fitur = encoder_cakapan.inverse_transform(pred_gabungan_fitur).reshape(301,)
pred_gabungan_keputusan = encoder_cakapan.inverse_transform(pred_gabungan_keputusan).reshape(301,)
true = y_true.reshape(301,)

# %%
raw = joblib.load(drive_dir + '/Eksperimen/Data/basic.pkl')
result = { 'Transkripsi': raw['Transkripsi'][test_index], 
          'Preprocessed' : data['Transkripsi'][test_index], 
          'Abstraksi Emosi' : true, 
          'Prediksi Model Akustik' : pred_akustik,
          'Confidence Level Model Akustik' : pred_akustik_proba,
          'Prediksi Model Leksikal' : pred_leksikal,
          'Confidence Level Model Leksikal' : pred_leksikal_proba,
          'Prediksi Model Gabungan Level Fitur' : pred_gabungan_fitur,
          'Confidence Level Model Gabungan Level Fitur' : pred_gabungan_fitur_proba,
          'Prediksi Model Gabungan Level Keputusan' : pred_gabungan_keputusan,
          'Confidence Level Model Gabungan Level Keputusan' : pred_gabungan_keputusan_proba,
          }
df = pd.DataFrame(result)
df.to_excel("output.xlsx") 
files.download('output.xlsx')
